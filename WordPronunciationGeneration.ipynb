# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, Input, LSTM, Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Data Reading

# %%
# !unzip '/content/cmudict.dict.zip'
# Out:
# Archive:  /content/cmudict.dict.zip
#   inflating: cmudict.dict

# %% [markdown]
# # DataFrame creation from Dictionary

# %%
'''
'bout B AW1 T
'cause K AH0 Z
'course K AO1 R S
'cuse K Y UW1 Z
'em AH0 M
'''





words = []
phonics_list = []

with open('/content/cmudict.dict', 'r') as f:
  phonics = [line.rstrip('\n') for line in f]
  for p in phonics:
    x = p.split(' ')
    #print(x)
    words.append(x[0])
    phonics_list.append(' '.join(x[1:]))

print(words[:10])
print(phonics_list[:10])
# Out:
# ["'bout", "'cause", "'course", "'cuse", "'em", "'frisco", "'gain", "'kay", "'m", "'n"]
# ['B AW1 T', 'K AH0 Z', 'K AO1 R S', 'K Y UW1 Z', 'AH0 M', 'F R IH1 S K OW0', 'G EH1 N', 'K EY1', 'AH0 M', 'AH0 N']

# %%
print(len(words))
print(len(phonics_list))
# Out:
# 135010
# 135010

# %%
df = pd.DataFrame({'Word': words, 'Phonics': phonics_list})
df.head()
# Out:
#       Word    Phonics
# 0    'bout    B AW1 T
# 1   'cause    K AH0 Z
# 2  'course  K AO1 R S
# 3    'cuse  K Y UW1 Z
# 4      'em      AH0 M

# %%
df = df.sample(100000).reset_index(drop=True)
df
# Out:
#               Word                  Phonics
# 0        patrolman  P AH0 T R OW1 L M AE2 N
# 1          samples        S AE1 M P AH0 L Z
# 2          tippy's            T IH1 P IY0 Z
# 3         mccready      M AH0 K R IY1 D IY0
# 4           sugden          S AH1 G D AH0 N
# ...            ...                      ...
# 99995       defray            D IH0 F R EY1
# 99996         zohn                  Z OW1 N
# 99997  superbowl's    S UW1 P ER0 B OW2 L Z
# 99998       stumpo          S T AH1 M P OW2
# 99999  response(2)        R IY0 S P AA1 N S
#
# [100000 rows x 2 columns]

# %% [markdown]
# # Data Prepocessing

# %% [markdown]
# ### 1. Adding start and end sequence

# %%
df['Phonics'] = 'startseq '+df['Phonics']+' endseq'
df
# Out:
#               Word                                  Phonics
# 0        patrolman  startseq P AH0 T R OW1 L M AE2 N endseq
# 1          samples        startseq S AE1 M P AH0 L Z endseq
# 2          tippy's            startseq T IH1 P IY0 Z endseq
# 3         mccready      startseq M AH0 K R IY1 D IY0 endseq
# 4           sugden          startseq S AH1 G D AH0 N endseq
# ...            ...                                      ...
# 99995       defray            startseq D IH0 F R EY1 endseq
# 99996         zohn                  startseq Z OW1 N endseq
# 99997  superbowl's    startseq S UW1 P ER0 B OW2 L Z endseq
# 99998       stumpo          startseq S T AH1 M P OW2 endseq
# 99999  response(2)        startseq R IY0 S P AA1 N S endseq
#
# [100000 rows x 2 columns]

# %%
max_len_ip = df['Word'].apply(lambda x: len(x)).max()
max_len_ip
# Out:
# 28

# %%
max_len_op = df['Phonics'].apply(lambda x: len(x.split())).max()
max_len_op
# Out:
# 30

# %% [markdown]
# ### 2. Tokenization
#
# i) characterwise tokenization in input sequence
#
# ii) wordwise tokenization in output sequence

# %%
words = df['Word'].tolist()
phonemes = df['Phonics'].tolist()

# %%
char_tokenizer = Tokenizer(char_level=True,oov_token='OOV')
char_tokenizer.fit_on_texts(words)
char_vocab_size = len(char_tokenizer.word_index) + 1
print("Character Vocab Size: ",char_vocab_size)
# Out:
# Character Vocab Size:  37

# %%
phone_tokenizer = Tokenizer(oov_token='OOV')
phone_tokenizer.fit_on_texts(phonemes)
phone_vocab_size = len(phone_tokenizer.word_index) + 1
print("Phoneme Vocab Size: ",phone_vocab_size)
# Out:
# Phoneme Vocab Size:  77

# %%
ch_sequences = char_tokenizer.texts_to_sequences(words)
ph_sequences = phone_tokenizer.texts_to_sequences(phonemes)

# %%
ch_sequences
# Out:
# [[17, 3, 9, 4, 8, 10, 13, 3, 7],
#  [6, 3, 13, 17, 10, 2, 6],
#  [9, 5, 17, 17, 20, 27, 6],
#  [13, 11, 11, 4, 2, 3, 12, 20],
#  [6, 14, 16, 12, 2, 7],
#  [6, 22, 5, 7, 16, 10, 2, 20],
#  [7, 16, 8, 4],
#  [11, 15, 3, 10, 21, 5, 7],
#  [14, 17, 15, 5, 10, 10],
#  [17, 5, 7, 6, 9, 4, 5, 17, 2, 6],
#  [18, 4, 2, 13],
#  [11, 15, 3, 17, 17, 2, 10],
#  [4, 2, 2, 21],
#  [12, 14, 3, 10],
#  [6, 9, 2, 21, 3],
#  [17, 3, 4, 9, 5, 11, 14, 10, 3, 4, 6],
#  [17, 5, 9, 11, 15, 2, 4, 27, 6],
#  [30, 3, 23, 5, 2, 4, 3],
#  [3, 10, 11, 8, 4, 9, 3],
#  [4, 5, 2, 6],
#  [6, 14, 4, 23, 2, 5, 10, 10, 3, 7, 11, 2],
#  [12, 3, 7, 16, 8],
#  [11, 14, 4, 3, 9, 2, 12],
#  [6, 17, 3, 11, 2, 17, 8, 4, 9],
#  [15, 2, 4, 4, 8, 7, 5, 13, 8, 27, 6],
#  [29, 14, 16, 16, 10, 2, 12],
#  [6, 15, 3, 4, 10, 2, 7, 2],
#  [11, 5, 23, 5, 10, 5, 3, 7],
#  [13, 5, 6, 4, 2, 3, 12],
#  [9, 5, 7, 19, 2, 4, 5, 7, 16],
#  [6, 2, 5, 12, 10, 2, 4],
#  [3, 13, 7, 5, 8, 11, 2, 7, 9, 2, 6, 5, 6],
#  [17, 10, 3, 11, 28, 2, 19],
#  [12, 2, 13, 3, 4, 9, 5, 7],
#  [19, 5, 7, 20, 8, 7],
#  [17, 8, 6, 9, 14, 13],
#  [4, 5, 9, 9, 6],
#  [3, 10, 10, 5, 7, 16],
#  [2, 30, 2, 11, 14, 9, 8, 4, 6],
#  [6, 14, 7, 12, 3, 15, 10],
#  [6, 14, 4, 17, 3, 6, 6],
#  [4, 2, 7, 12, 10, 2, 13, 3, 7],
#  [18, 3, 4, 2, 21, 5, 2, 10, 12, 24, 26, 25],
#  [9, 15, 8, 13, 3, 7, 7],
#  [17, 4, 8, 18, 3, 18, 10, 20, 24, 26, 25],
#  [13, 5, 6, 5, 7, 21, 8, 4, 13],
#  [9, 15, 2, 5, 6, 6],
#  [11, 8, 9, 9, 8, 13],
#  [3, 4, 3, 18, 5, 11],
#  [10, 8, 8, 9, 2, 12],
#  [13, 5],
#  [11, 8, 7, 10, 2, 20],
#  [16, 8, 3, 9, 2, 2],
#  [19, 3, 7, 28],
#  [17, 3, 4, 4, 5, 7, 2, 10, 10, 8],
#  [10, 3, 7, 12, 8, 10, 21, 5],
#  [10, 20, 19, 2],
#  [29, 3, 22, 8, 4, 6, 19, 5],
#  [16, 4, 3, 14, 13, 3, 7, 7],
#  [15, 2, 7, 12, 4, 20],
#  [3, 12, 15, 2, 4, 2, 7, 9, 6],
#  [15, 2, 5, 7, 2],
#  [15, 3, 4, 23, 5, 10, 10, 2],
#  [15, 2, 7, 4, 5, 11, 19, 6, 2, 7],
#  [10, 3, 4, 8, 6, 5, 2, 4, 2],
#  [10, 3, 17, 5, 7, 6, 19, 20],
#  [11, 15, 8, 17, 4, 3],
#  [23, 3, 7, 18, 14, 4, 2, 7],
#  [5, 7, 12, 5, 11, 3, 9, 2, 12, 24, 26, 25],
#  [13, 3, 9, 8, 11, 8],
#  [19, 3, 7, 3, 4, 2, 19],
#  [9, 3, 4, 9, 3, 16, 10, 5, 8, 7, 2],
#  [6, 17, 4, 14, 5, 10, 10],
#  [17, 5, 17, 15, 2, 4],
#  [15, 2, 18, 2],
#  [15, 14, 7, 9, 10, 2, 20],
#  [21, 8, 8, 12, 6],
#  [23, 2, 7, 9, 14, 4, 2, 10, 10, 3],
#  [15, 3, 10, 10, 14, 13],
#  [5, 13, 13, 5, 16, 4, 3, 7, 9, 27, 6],
#  [13, 2, 7, 16, 15, 5, 7, 5],
#  [6, 17, 10, 14, 4, 16, 2, 12],
#  [6, 8, 10, 5, 7, 16, 2, 7, 24, 26, 25],
#  [22, 5, 2, 6, 6, 7, 2, 4],
#  [6, 9, 3, 9, 6],
#  [12, 2, 17, 5, 11, 9, 2, 12, 24, 26, 25],
#  [9, 15, 8, 4, 2, 3, 14],
#  [13, 2, 7, 2, 21, 2, 2],
#  [12, 2, 13, 8, 7, 6, 9, 4, 3, 9, 8, 4],
#  [8, 13, 3, 4],
#  [21, 8, 7, 12],
#  [9, 2, 9, 2, 4, 6],
#  [3, 23, 5, 3, 10, 10],
#  [9, 8, 4, 10, 2, 20],
#  [21, 10, 2, 6, 15],
#  [14, 7, 21, 3, 23, 8, 4, 3, 18, 10, 2],
#  [10, 14, 13, 18, 2, 4, 5, 7, 16],
#  [10, 3, 3, 9, 6, 11, 15],
#  [6, 28, 8, 6, 9, 2, 19],
#  [13, 3, 23, 3, 4, 3, 11, 15],
#  [15, 2, 12, 4, 5, 11, 15],
#  [21, 5, 2, 6, 2, 4],
#  [17, 2, 4, 6, 17, 5, 11, 3, 11, 5, 8, 14, 6],
#  [16, 3, 4, 9, 10, 3, 7, 12],
#  [11, 4, 2, 9, 2, 10, 10, 3],
#  [9, 20, 11, 8, 8, 7, 6],
#  [15, 3, 22, 3, 5, 5],
#  [21, 4, 3, 13, 2, 4],
#  [10, 3, 20, 8, 21, 21],
#  [13, 2, 6, 6, 20],
#  [4, 8, 18, 18, 2, 4, 5, 2, 6],
#  [6, 8, 14, 9, 15, 5, 7],
#  [6, 17, 3, 12, 3, 11, 11, 5, 7, 5],
#  [3, 13, 13, 8, 7],
#  [4, 8, 11, 15, 18, 2, 4, 16],
#  [6, 15, 3, 13, 18, 8],
#  [5, 13, 5, 9, 3, 9, 8, 4],
#  ...]

# %%
ph_sequences
# Out:
# [[2, 19, 4, 8, 9, 32, 7, 13, 45, 5, 3],
#  [2, 6, 21, 13, 19, 4, 7, 14, 3],
#  [2, 8, 22, 19, 16, 14, 3],
#  [2, 13, 4, 10, 9, 26, 11, 16, 3],
#  [2, 6, 36, 24, 11, 4, 5, 3],
#  [2, 6, 30, 22, 27, 24, 7, 16, 3],
#  [2, 50, 27, 24, 34, 9, 3],
#  [2, 41, 21, 7, 23, 12, 5, 3],
#  [2, 36, 19, 29, 22, 7, 3],
#  [2, 19, 22, 5, 6, 8, 9, 46, 19, 6, 3],
#  [2, 17, 9, 18, 13, 3],
#  [2, 41, 21, 19, 4, 7, 3],
#  [2, 9, 26, 23, 3],
#  [2, 11, 37, 4, 7, 3],
#  [2, 6, 8, 18, 23, 4, 3],
#  [2, 19, 15, 8, 22, 10, 39, 4, 7, 15, 14, 3],
#  [2, 19, 22, 41, 15, 14, 3],
#  [2, 14, 63, 25, 39, 18, 9, 4, 3],
#  [2, 40, 7, 10, 34, 9, 8, 4, 3],
#  [2, 9, 35, 14, 3],
#  [2, 6, 15, 25, 28, 7, 4, 5, 6, 3],
#  [2, 11, 21, 27, 24, 33, 3],
#  [2, 10, 39, 70, 9, 28, 8, 12, 11, 3],
#  [2, 6, 19, 28, 6, 19, 55, 9, 8, 3],
#  [2, 29, 15, 20, 5, 4, 13, 33, 14, 3],
#  [2, 38, 36, 24, 4, 7, 11, 3],
#  [2, 31, 20, 9, 7, 51, 5, 3],
#  [2, 6, 4, 25, 22, 7, 39, 4, 5, 3],
#  [2, 13, 12, 6, 9, 26, 11, 3],
#  [2, 8, 22, 27, 10, 15, 12, 27, 3],
#  [2, 6, 35, 11, 7, 15, 3],
#  [2, 45, 13, 5, 16, 33, 6, 44, 5, 8, 26, 6, 12, 6, 3],
#  [2, 19, 7, 20, 41, 50, 10, 3],
#  [2, 11, 12, 13, 20, 9, 8, 12, 5, 3],
#  [2, 10, 22, 5, 39, 4, 5, 3],
#  [2, 19, 32, 6, 8, 4, 13, 3],
#  [2, 9, 22, 8, 6, 3],
#  [2, 34, 7, 12, 27, 3],
#  [2, 12, 24, 14, 18, 10, 39, 4, 8, 15, 14, 3],
#  [2, 6, 36, 5, 11, 47, 7, 3],
#  [2, 6, 15, 19, 21, 6, 3],
#  [2, 9, 18, 5, 11, 4, 7, 13, 4, 5, 3],
#  [2, 17, 21, 9, 23, 16, 7, 11, 3],
#  [2, 66, 32, 13, 4, 5, 3],
#  [2, 19, 9, 20, 17, 7, 16, 3],
#  [2, 13, 12, 6, 43, 5, 23, 34, 9, 13, 3],
#  [2, 49, 35, 6, 3],
#  [2, 10, 20, 8, 4, 13, 3],
#  [2, 21, 9, 4, 17, 12, 10, 3],
#  [2, 7, 37, 8, 4, 11, 3],
#  [2, 13, 26, 3],
#  [2, 10, 20, 5, 7, 16, 3],
#  [2, 24, 32, 8, 26, 3],
#  [2, 10, 21, 5, 14, 3],
#  [2, 19, 40, 9, 16, 5, 18, 7, 33, 3],
#  [2, 7, 40, 5, 11, 32, 7, 23, 16, 3],
#  [2, 7, 35, 10, 3],
#  [2, 38, 4, 30, 34, 9, 6, 10, 16, 3],
#  [2, 24, 9, 34, 13, 4, 5, 3],
#  [2, 29, 18, 5, 11, 9, 16, 3],
#  [2, 56, 11, 29, 22, 9, 4, 5, 8, 6, 3],
#  [2, 29, 35, 5, 3],
#  [2, 29, 20, 9, 25, 43, 7, 3],
#  [2, 29, 18, 5, 9, 12, 10, 6, 4, 5, 3],
#  [2, 7, 40, 9, 33, 6, 39, 18, 9, 3],
#  [2, 7, 4, 19, 22, 5, 6, 10, 16, 3],
#  [2, 41, 20, 19, 9, 4, 3],
#  [2, 25, 56, 5, 17, 39, 37, 9, 4, 5, 3],
#  [2, 22, 5, 11, 4, 10, 48, 8, 12, 11, 3],
#  [2, 13, 4, 8, 34, 10, 33, 3],
#  [2, 10, 21, 5, 15, 12, 10, 3],
#  [2, 8, 40, 9, 8, 56, 24, 7, 16, 32, 5, 16, 3],
#  [2, 6, 19, 9, 37, 7, 3],
#  [2, 19, 22, 23, 15, 3],
#  [2, 29, 26, 17, 3],
#  [2, 29, 36, 5, 8, 7, 16, 3],
#  [2, 23, 37, 11, 14, 3],
#  [2, 25, 50, 5, 8, 70, 9, 18, 7, 4, 3],
#  [2, 29, 21, 7, 4, 13, 3],
#  [2, 22, 13, 4, 24, 9, 4, 5, 8, 6, 3],
#  [2, 13, 50, 5, 24, 26, 5, 16, 3],
#  [2, 6, 19, 7, 42, 38, 11, 3],
#  [2, 6, 20, 7, 12, 27, 24, 50, 5, 3],
#  [2, 30, 26, 6, 5, 15, 3],
#  [2, 6, 8, 21, 8, 6, 3],
#  [2, 11, 12, 19, 22, 10, 8, 12, 11, 3],
#  [2, 49, 15, 32, 3],
#  [2, 13, 18, 5, 12, 23, 16, 3],
#  [2, 11, 18, 13, 4, 5, 6, 8, 9, 48, 8, 15, 3],
#  [2, 32, 13, 40, 9, 3],
#  [2, 23, 20, 5, 11, 3],
#  [2, 8, 26, 8, 15, 14, 3],
#  [2, 28, 25, 16, 4, 7, 3],
#  [2, 8, 34, 9, 7, 16, 3],
#  [2, 23, 7, 18, 31, 3],
#  [2, 61, 5, 23, 28, 25, 15, 4, 17, 4, 7, 3],
#  [2, 7, 36, 13, 17, 15, 12, 27, 3],
#  [2, 7, 20, 41, 3],
#  [2, 31, 20, 6, 8, 50, 10, 3],
#  [2, 13, 4, 25, 20, 9, 4, 41, 3],
#  [2, 29, 18, 11, 9, 12, 10, 3],
#  [2, 23, 26, 6, 15, 3],
#  [2, 19, 15, 6, 19, 4, 10, 28, 31, 4, 6, 3],
#  [2, 24, 20, 9, 8, 7, 4, 5, 11, 3],
#  [2, 10, 9, 50, 8, 18, 7, 4, 3],
#  [2, 8, 59, 10, 37, 5, 14, 3],
#  [2, 29, 4, 30, 35, 51, 3],
#  [2, 23, 9, 28, 13, 15, 3],
#  [2, 23, 9, 26, 10, 30, 44, 5, 8, 6, 3],
#  [2, 5, 37, 25, 44, 10, 8, 15, 3],
#  [2, 10, 28, 11, 12, 27, 3],
#  [2, 43, 5, 8, 15, 9, 16, 7, 28, 8, 12, 11, 3],
#  [2, 17, 21, 8, 4, 7, 14, 3],
#  [2, 29, 21, 5, 31, 54, 3],
#  [2, 10, 18, 5, 11, 12, 24, 3],
#  [2, 19, 39, 57, 9, 12, 6, 8, 6, 3],
#  [2, 8, 35, 8, 13, 46, 9, 3],
#  [2, 41, 36, 13, 17, 7, 16, 3],
#  [2, 24, 20, 9, 11, 4, 5, 15, 14, 3],
#  [2, 6, 19, 44, 6, 12, 23, 12, 10, 28, 31, 4, 5, 3],
#  [2, 5, 34, 9, 11, 3],
#  [2, 10, 21, 27, 10, 12, 10, 16, 3],
#  [2, 29, 36, 5, 41, 8, 3],
#  [2, 8, 53, 15, 14, 3],
#  [2, 6, 10, 34, 7, 11, 12, 27, 3],
#  [2, 13, 47, 9, 6, 22, 24, 7, 16, 4, 3],
#  [2, 29, 32, 24, 16, 3],
#  [2, 43, 5, 8, 32, 5, 14, 3],
#  [2, 11, 21, 13, 19, 12, 27, 3],
#  [2, 25, 15, 13, 20, 5, 8, 6, 3],
#  [2, 11, 22, 66, 15, 3],
#  [2, 5, 22, 10, 58, 7, 3],
#  [2, 30, 22, 7, 4, 13, 6, 4, 5, 3],
#  [2, 17, 34, 10, 8, 3],
#  [2, 28, 25, 12, 27, 15, 3],
#  [2, 8, 44, 29, 15, 20, 5, 14, 3],
#  [2, 19, 9, 4, 29, 20, 6, 10, 4, 3],
#  [2, 40, 9, 5, 36, 7, 23, 33, 3],
#  [2, 24, 9, 18, 5, 3],
#  [2, 10, 9, 22, 6, 8, 4, 17, 44, 7, 3],
#  [2, 38, 18, 7, 16, 3],
#  [2, 9, 37, 5, 3],
#  [2, 39, 37, 5, 4, 8, 6, 3],
#  [2, 7, 32, 5, 7, 55, 6, 3],
#  [2, 25, 21, 5, 11, 15, 10, 52, 10, 3],
#  [2, 24, 57, 11, 5, 46, 8, 3],
#  [2, 9, 12, 6, 8, 34, 9, 12, 27, 3],
#  [2, 7, 16, 41, 26, 8, 9, 4, 3],
#  [2, 31, 18, 19, 15, 3],
#  [2, 10, 9, 62, 3],
#  [2, 7, 15, 28, 5, 3],
#  [2, 19, 30, 47, 9, 32, 3],
#  [2, 23, 20, 66, 15, 7, 45, 5, 11, 3],
#  [2, 7, 22, 13, 3],
#  [2, 10, 26, 7, 16, 3],
#  [2, 17, 20, 49, 12, 6, 8, 6, 3],
#  [2, 9, 48, 11, 16, 4, 7, 20, 38, 12, 10, 4, 7, 3],
#  [2, 23, 22, 7, 4, 5, 3],
#  [2, 41, 62, 6, 3],
#  [2, 4, 6, 34, 7, 8, 6, 3],
#  [2, 6, 34, 13, 3],
#  [2, 4, 6, 21, 6, 4, 5, 3],
#  [2, 11, 12, 7, 18, 23, 6, 10, 16, 3],
#  [2, 19, 9, 26, 6, 8, 3],
#  [2, 10, 21, 13, 59, 15, 3],
#  [2, 13, 43, 14, 15, 20, 17, 3],
#  [2, 11, 9, 28, 10, 6, 3],
#  [2, 6, 36, 23, 4, 10, 48, 8, 12, 27, 3],
#  [2, 9, 32, 41, 15, 3],
#  [2, 13, 18, 9, 12, 6, 44, 7, 3],
#  [2, 23, 28, 7, 56, 27, 10, 6, 3],
#  [2, 7, 32, 4, 5, 6, 8, 51, 5, 3],
#  [2, 25, 32, 7, 10, 15, 14, 3],
#  [2, 18, 7, 33, 16, 14, 3],
#  [2, 36, 7, 8, 4, 13, 4, 8, 3],
#  [2, 24, 9, 12, 24, 34, 9, 16, 33, 3],
#  [2, 11, 21, 25, 10, 33, 3],
#  [2, 30, 18, 5, 14, 7, 12, 10, 3],
#  [2, 11, 26, 11, 3],
#  [2, 31, 26, 10, 6, 3],
#  [2, 16, 5, 34, 9, 13, 4, 8, 16, 3],
#  [2, 24, 35, 6, 4, 7, 13, 4, 5, 3],
#  [2, 29, 21, 5, 11, 16, 10, 45, 19, 3],
#  [2, 12, 23, 39, 37, 6, 12, 25, 7, 16, 3],
#  [2, 34, 5, 4, 27, 6, 8, 3],
#  [2, 10, 12, 14, 13, 20, 39, 54, 3],
#  [2, 6, 18, 5, 15, 3],
#  [2, 7, 12, 62, 5, 3],
#  [2, 17, 34, 9, 5, 15, 3],
#  [2, 7, 16, 10, 34, 6, 51, 3],
#  [2, 53, 8, 12, 5, 9, 16, 12, 49, 3],
#  [2, 19, 40, 5, 8, 22, 23, 4, 10, 48, 8, 15, 14, 3],
#  [2, 7, 18, 8, 4, 3],
#  [2, 11, 21, 7, 10, 4, 5, 3],
#  [2, 5, 26, 29, 64, 6, 3],
#  [2, 10, 20, 9, 7, 14, 3],
#  [2, 58, 9, 18, 7, 16, 4, 3],
#  [2, 5, 22, 10, 7, 4, 6, 3],
#  [2, 13, 22, 7, 12, 6, 44, 10, 4, 5, 11, 14, 3],
#  [2, 9, 16, 11, 18, 10, 15, 48, 8, 12, 27, 3],
#  [2, 15, 25, 18, 8, 3],
#  [2, 29, 34, 10, 17, 43, 7, 3],
#  [2, 10, 9, 22, 6, 8, 4, 7, 14, 3],
#  [2, 30, 18, 6, 8, 41, 44, 6, 8, 15, 3],
#  [2, 8, 58, 9, 28, 3],
#  [2, 7, 32, 66, 6, 4, 13, 3],
#  [2, 39, 20, 6, 15, 3],
#  [2, 4, 13, 18, 9, 12, 10, 4, 5, 46, 14, 11, 3],
#  [2, 50, 13, 19, 7, 62, 12, 27, 3],
#  [2, 7, 21, 5, 23, 43, 9, 3],
#  [2, 29, 35, 13, 14, 3],
#  [2, 4, 17, 14, 42, 25, 4, 5, 6, 12, 14, 3],
#  [2, 13, 40, 27, 24, 32, 7, 39, 4, 5, 3],
#  [2, 23, 18, 7, 11, 15, 3],
#  [2, 30, 22, 13, 17, 15, 7, 16, 3],
#  [2, 17, 33, 5, 26, 5, 33, 3],
#  [2, 6, 40, 7, 25, 20, 8, 16, 3],
#  [2, 34, 49, 15, 14, 3],
#  [2, 13, 20, 9, 14, 12, 10, 3],
#  [2, 6, 4, 17, 38, 18, 10, 8, 12, 25, 3],
#  [2, 7, 39, 37, 4, 5, 3],
#  [2, 11, 32, 17, 9, 52, 3],
#  [2, 11, 42, 29, 4, 13, 3],
#  [2, 38, 35, 5, 3],
#  [2, 4, 6, 37, 13, 3],
#  [2, 29, 30, 35, 8, 30, 55, 8, 15, 3],
#  [2, 18, 11, 30, 15, 11, 14, 3],
#  [2, 13, 4, 10, 7, 21, 41, 16, 3],
#  [2, 38, 37, 5, 33, 3],
#  [2, 24, 4, 7, 36, 6, 10, 4, 3],
#  [2, 6, 8, 21, 5, 38, 3],
#  [2, 30, 43, 7, 4, 13, 18, 8, 3],
#  [2, 21, 11, 43, 10, 8, 3],
#  [2, 8, 35, 19, 4, 7, 15, 3],
#  [2, 10, 20, 5, 8, 4, 6, 3],
#  [2, 6, 9, 48, 17, 9, 50, 5, 26, 8, 6, 4, 14, 3],
#  [2, 6, 32, 7, 15, 3],
#  [2, 32, 25, 15, 4, 10, 15, 3],
#  [2, 13, 34, 5, 4, 3],
#  [2, 22, 5, 4, 6, 4, 5, 8, 6, 3],
#  [2, 10, 20, 10, 5, 16, 3],
#  [2, 38, 20, 5, 4, 49, 4, 5, 3],
#  [2, 31, 21, 5, 4, 29, 56, 5, 3],
#  [2, 9, 22, 24, 14, 3],
#  [2, 13, 21, 27, 24, 4, 5, 3],
#  [2, 24, 36, 38, 15, 3],
#  [2, 28, 11, 16, 3],
#  [2, 19, 21, 10, 4, 38, 4, 14, 3],
#  [2, 43, 5, 6, 42, 38, 4, 5, 6, 16, 3],
#  [2, 23, 62, 17, 4, 7, 14, 3],
#  [2, 19, 9, 20, 23, 4, 6, 16, 3],
#  [2, 38, 34, 9, 24, 12, 5, 6, 4, 5, 3],
#  [2, 29, 18, 7, 10, 3],
#  [2, 20, 7, 12, 25, 18, 8, 3],
#  [2, 43, 5, 25, 44, 6, 8, 4, 24, 28, 31, 4, 5, 3],
#  [2, 44, 9, 12, 8, 9, 26, 4, 3],
#  [2, 10, 9, 22, 41, 8, 4, 5, 3],
#  [2, 34, 7, 17, 9, 46, 8, 6, 25, 12, 7, 3],
#  [2, 10, 28, 25, 14, 3],
#  [2, 25, 9, 26, 11, 4, 5, 17, 15, 24, 3],
#  [2, 10, 4, 13, 42, 31, 4, 7, 46, 14, 3],
#  [2, 43, 13, 19, 9, 22, 5, 8, 12, 27, 3],
#  [2, 61, 5, 10, 4, 5, 25, 22, 5, 6, 12, 27, 3],
#  [2, 9, 28, 6, 16, 3],
#  [2, 19, 4, 7, 22, 8, 12, 6, 46, 14, 11, 3],
#  [2, 29, 20, 8, 7, 50, 8, 3],
#  [2, 33, 29, 18, 9, 3],
#  [2, 29, 30, 28, 7, 12, 27, 3],
#  [2, 25, 42, 24, 16, 3],
#  [2, 13, 57, 9, 3],
#  [2, 5, 32, 3],
#  [2, 19, 20, 17, 7, 33, 3],
#  [2, 25, 32, 24, 12, 7, 16, 3],
#  [2, 7, 21, 27, 24, 30, 15, 49, 3],
#  [2, 7, 40, 17, 40, 9, 17, 18, 9, 4, 3],
#  [2, 24, 9, 34, 13, 4, 5, 3],
#  [2, 8, 21, 10, 6, 47, 7, 3],
#  [2, 43, 5, 6, 10, 9, 35, 17, 14, 3],
#  [2, 23, 7, 18, 31, 3],
#  [2, 11, 18, 7, 10, 56, 13, 19, 3],
#  [2, 31, 5, 21, 10, 3],
#  [2, 14, 21, 13, 17, 16, 4, 14, 3],
#  [2, 10, 15, 26, 10, 33, 3],
#  [2, 11, 22, 13, 12, 10, 6, 3],
#  [2, 11, 35, 5, 4, 6, 55, 9, 3],
#  [2, 30, 34, 9, 11, 3],
#  [2, 10, 21, 9, 12, 24, 3],
#  [2, 39, 32, 10, 50, 7, 6, 4, 5, 3],
#  [2, 18, 9, 8, 6, 3],
#  [2, 6, 10, 28, 5, 14, 3],
#  [2, 17, 28, 6, 4, 5, 14, 3],
#  [2, 10, 9, 33, 10, 28, 3],
#  [2, 12, 5, 24, 9, 32, 6, 13, 4, 5, 8, 3],
#  [2, 17, 7, 37, 12, 31, 3],
#  [2, 24, 18, 17, 29, 15, 11, 3],
#  [2, 13, 52, 8, 33, 29, 20, 31, 16, 3],
#  [2, 17, 18, 5, 38, 16, 3],
#  [2, 41, 54, 24, 32, 10, 60, 3],
#  [2, 9, 20, 10, 7, 16, 3],
#  [2, 41, 9, 51, 17, 33, 5, 26, 10, 33, 14, 3],
#  [2, 22, 13, 39, 54, 7, 47, 38, 12, 10, 3],
#  [2, 13, 18, 7, 12, 8, 3],
#  [2, 28, 6, 4, 6, 3],
#  [2, 9, 48, 11, 16, 33, 21, 10, 8, 12, 25, 3],
#  [2, 11, 35, 7, 12, 27, 3],
#  [2, 18, 9, 7, 46, 5, 3],
#  [2, 6, 10, 30, 34, 10, 12, 27, 3],
#  [2, 21, 10, 31, 4, 7, 16, 3],
#  [2, 6, 26, 29, 55, 10, 3],
#  [2, 50, 7, 20, 8, 4, 3],
#  [2, 14, 22, 13, 17, 4, 7, 13, 4, 5, 3],
#  [2, 26, 13, 15, 38, 3],
#  [2, 19, 9, 22, 5, 6, 50, 6, 12, 14, 3],
#  [2, 46, 6, 51, 6, 26, 3],
#  [2, 10, 18, 13, 4, 10, 4, 7, 3],
#  [2, 6, 52, 6, 16, 20, 7, 4, 38, 16, 3],
#  [2, 23, 42, 5, 12, 41, 15, 3],
#  [2, 19, 7, 28, 8, 12, 27, 3],
#  [2, 4, 6, 21, 6, 4, 5, 48, 8, 3],
#  [2, 4, 5, 23, 21, 66, 4, 13, 4, 17, 4, 7, 3],
#  [2, 24, 35, 10, 33, 3],
#  [2, 11, 45, 7, 23, 20, 5, 6, 33, 3],
#  [2, 22, 5, 11, 4, 10, 48, 8, 4, 11, 3],
#  [2, 33, 10, 18, 7, 16, 3],
#  [2, 29, 18, 7, 11, 9, 12, 49, 3],
#  [2, 20, 25, 59, 6, 3],
#  [2, 6, 19, 22, 5, 4, 41, 3],
#  [2, 5, 18, 8, 30, 65, 10, 6, 3],
#  [2, 19, 22, 24, 6, 8, 46, 3],
#  [2, 12, 10, 47, 5, 4, 13, 18, 8, 9, 12, 10, 6, 3],
#  [2, 6, 30, 12, 8, 20, 7, 4, 3],
#  [2, 31, 21, 5, 8, 33, 3],
#  [2, 19, 36, 27, 10, 12, 5, 3],
#  [2, 4, 6, 35, 5, 13, 4, 5, 8, 6, 3],
#  [2, 7, 21, 13, 19, 3],
#  [2, 17, 7, 35, 8, 12, 11, 3],
#  [2, 31, 18, 9, 4, 8, 4, 5, 3],
#  [2, 10, 4, 41, 28, 11, 33, 3],
#  [2, 61, 5, 4, 11, 9, 18, 6, 8, 3],
#  [2, 49, 9, 34, 7, 3],
#  [2, 6, 40, 14, 20, 13, 4, 3],
#  [2, 9, 12, 8, 34, 9, 12, 10, 4, 7, 3],
#  [2, 29, 30, 22, 6, 7, 15, 3],
#  [2, 47, 19, 15, 21, 5, 11, 16, 3],
#  [2, 28, 7, 3],
#  [2, 5, 37, 4, 38, 3],
#  [2, 18, 9, 4, 3],
#  [2, 6, 50, 7, 53, 6, 10, 16, 3],
#  [2, 21, 11, 25, 50, 6, 8, 3],
#  [2, 5, 37, 23, 53, 5, 11, 3],
#  [2, 19, 9, 4, 19, 22, 31, 4, 6, 3],
#  [2, 7, 36, 5, 8, 3],
#  [2, 25, 28, 7, 3],
#  [2, 25, 56, 5, 7, 22, 9, 3],
#  [2, 18, 6, 4, 7, 13, 4, 5, 3],
#  [2, 4, 13, 45, 7, 24, 4, 13, 28, 31, 4, 5, 3],
#  [2, 4, 5, 36, 66, 15, 3],
#  [2, 6, 40, 25, 16, 20, 5, 33, 3],
#  [2, 40, 7, 62, 6, 4, 3],
#  [2, 19, 9, 20, 17, 7, 4, 13, 14, 3],
#  [2, 4, 7, 22, 8, 15, 4, 8, 12, 25, 3],
#  [2, 23, 21, 5, 16, 3],
#  [2, 13, 4, 10, 5, 26, 7, 3],
#  [2, 6, 22, 5, 11, 9, 52, 13, 14, 3],
#  [2, 11, 12, 9, 28, 7, 14, 3],
#  [2, 6, 8, 36, 23, 3],
#  [2, 38, 15, 17, 32, 4, 14, 3],
#  [2, 17, 21, 27, 3],
#  [2, 23, 9, 26, 11, 15, 10, 43, 27, 3],
#  [2, 43, 27, 10, 20, 8, 4, 3],
#  [2, 5, 18, 6, 16, 3],
#  [2, 17, 9, 28, 10, 16, 46, 3],
#  [2, 18, 5, 11, 15, 4, 5, 6, 3],
#  [2, 10, 20, 7, 13, 5, 4, 6, 3],
#  [2, 8, 30, 42, 6, 10, 16, 3],
#  [2, 4, 7, 35, 14, 3],
#  [2, 9, 60, 13, 4, 8, 20, 7, 4, 38, 16, 3],
#  [2, 23, 65, 13, 4, 5, 8, 28, 31, 4, 5, 3],
#  [2, 10, 28, 7, 16, 3],
#  [2, 33, 23, 7, 28, 15, 8, 16, 3],
#  [2, 8, 32, 17, 16, 3],
#  [2, 11, 9, 36, 13, 29, 44, 7, 15, 3],
#  [2, 19, 36, 5, 41, 12, 14, 3],
#  [2, 6, 19, 9, 22, 27, 6, 8, 4, 5, 3],
#  [2, 5, 47, 10, 4, 6, 32, 5, 16, 14, 3],
#  [2, 10, 20, 8, 7, 15, 3],
#  [2, 9, 35, 13, 11, 3],
#  [2, 6, 8, 26, 38, 4, 13, 46, 9, 3],
#  [2, 6, 8, 34, 9, 13, 33, 5, 8, 3],
#  [2, 19, 26, 7, 15, 3],
#  [2, 7, 45, 10, 8, 33, 17, 4, 6, 22, 7, 4, 6, 3],
#  [2, 7, 35, 23, 12, 6, 8, 3],
#  [2, 31, 37, 8, 6, 3],
#  [2, 17, 21, 8, 4, 7, 23, 51, 7, 11, 3],
#  [2, 23, 58, 9, 6, 26, 12, 27, 3],
#  [2, 23, 26, 4, 11, 15, 3],
#  [2, 29, 21, 5, 11, 13, 28, 11, 3],
#  [2, 10, 22, 13, 4, 7, 3],
#  [2, 11, 12, 13, 26, 5, 52, 3],
#  [2, 7, 28, 64, 8, 6, 3],
#  [2, 10, 36, 7, 19, 12, 19, 15, 3],
#  [2, 17, 32, 7, 31, 4, 25, 43, 10, 3],
#  [2, 13, 34, 9, 4, 30, 43, 10, 3],
#  [2, 14, 28, 11, 47, 9, 3],
#  [2, 23, 18, 7, 11, 13, 39, 60, 7, 4, 3],
#  [2, 39, 4, 25, 4, 5, 20, 25, 12, 10, 3],
#  [2, 31, 4, 17, 62, 24, 4, 5, 3],
#  [2, 29, 18, 8, 6, 7, 15, 3],
#  [2, 7, 26, 19, 23, 9, 55, 24, 11, 3],
#  [2, 23, 7, 22, 6, 3],
#  [2, 11, 28, 7, 55, 27, 3],
#  [2, 35, 15, 5, 3],
#  [2, 17, 22, 7, 50, 10, 3],
#  [2, 17, 20, 8, 4, 13, 23, 43, 31, 3],
#  [2, 7, 50, 8, 22, 9, 16, 3],
#  [2, 4, 5, 42, 5, 11, 3],
#  [2, 11, 18, 13, 54, 7, 56, 5, 3],
#  [2, 11, 21, 19, 15, 3],
#  [2, 21, 13, 12, 10, 4, 17, 7, 16, 3],
#  [2, 10, 9, 22, 6, 8, 3],
#  [2, 13, 4, 6, 10, 26, 8, 33, 14, 3],
#  [2, 13, 36, 6, 4, 5, 8, 3],
#  [2, 6, 8, 26, 13, 17, 52, 8, 3],
#  [2, 44, 19, 4, 11, 18, 13, 12, 10, 6, 3],
#  [2, 14, 37, 24, 4, 5, 55, 25, 6, 3],
#  [2, 21, 6, 8, 4, 5, 3],
#  [2, 19, 20, 6, 8, 4, 3],
#  [2, 25, 20, 9, 5, 15, 3],
#  [2, 17, 18, 8, 12, 5, 11, 58, 9, 23, 3],
#  [2, 23, 9, 26, 30, 48, 14, 3],
#  [2, 21, 6, 7, 12, 6, 4, 5, 3],
#  [2, 19, 18, 9, 12, 6, 3],
#  [2, 17, 20, 9, 8, 51, 3],
#  [2, 19, 7, 21, 8, 4, 19, 68, 6, 3],
#  [2, 9, 16, 24, 9, 37, 19, 3],
#  [2, 19, 21, 27, 3],
#  [2, 18, 23, 9, 4, 5, 3],
#  [2, 32, 25, 15, 7, 47, 10, 3],
#  [2, 25, 18, 10, 6, 12, 14, 3],
#  [2, 6, 30, 22, 27, 12, 27, 3],
#  [2, 11, 70, 9, 20, 5, 11, 3],
#  [2, 29, 18, 7, 13, 14, 7, 16, 14, 3],
#  [2, 10, 34, 9, 11, 4, 3],
#  [2, 6, 5, 36, 24, 12, 27, 3],
#  [2, 25, 18, 7, 8, 3],
#  [2, 6, 20, 11, 3],
#  [2, 13, 12, 5, 20, 9, 11, 33, 6, 3],
#  [2, 11, 9, 21, 23, 8, 6, 3],
#  [2, 38, 4, 5, 20, 9, 11, 4, 5, 3],
#  [2, 19, 26, 10, 54, 3],
#  [2, 17, 9, 4, 6, 32, 3],
#  [2, 13, 44, 24, 4, 10, 21, 9, 39, 15, 14, 3],
#  [2, 7, 21, 9, 16, 4, 3],
#  [2, 23, 9, 28, 67, 15, 14, 3],
#  [2, 23, 18, 6, 8, 15, 11, 3],
#  [2, 23, 22, 5, 6, 8, 9, 4, 13, 3],
#  [2, 13, 63, 5, 8, 28, 5, 14, 3],
#  [2, 13, 42, 8, 12, 5, 14, 3],
#  [2, 19, 9, 35, 13, 12, 27, 3],
#  [2, 17, 28, 14, 3],
#  [2, 10, 20, 9, 8, 4, 7, 12, 38, 3],
#  [2, 8, 20, 5, 8, 52, 3],
#  [2, 29, 22, 19, 5, 4, 8, 46, 14, 11, 3],
#  [2, 38, 62, 49, 9, 43, 7, 3],
#  [2, 6, 19, 18, 10, 8, 9, 4, 14, 3],
#  [2, 11, 12, 6, 19, 18, 9, 12, 27, 3],
#  [2, 6, 19, 22, 9, 4, 3],
#  [2, 13, 22, 9, 16, 4, 11, 3],
#  [2, 17, 36, 11, 16, 3],
#  [2, 19, 7, 21, 5, 8, 12, 23, 6, 3],
#  [2, 23, 40, 9, 40, 32, 5, 16, 3],
#  [2, 19, 32, 7, 6, 12, 5, 3],
#  [2, 19, 16, 10, 20, 5, 8, 63, 3],
#  [2, 9, 28, 19, 15, 3],
#  [2, 9, 47, 25, 16, 31, 20, 27, 10, 47, 9, 3],
#  [2, 10, 9, 32, 5, 3],
#  [2, 9, 22, 13, 14, 3],
#  [2, 13, 58, 9, 18, 7, 3],
#  [2, 7, 26, 6, 16, 3],
#  [2, 10, 9, 57, 10, 6, 8, 4, 5, 3],
#  [2, 6, 19, 18, 9, 12, 27, 7, 16, 3],
#  [2, 18, 9, 12, 10, 4, 3],
#  [2, 23, 33, 5, 6, 18, 10, 4, 3],
#  [2, 19, 4, 7, 22, 8, 4, 10, 4, 7, 3],
#  [2, 9, 28, 3],
#  [2, 24, 20, 9, 23, 43, 27, 10, 4, 7, 3],
#  [2, 9, 44, 5, 4, 6, 20, 5, 6, 12, 14, 3],
#  [2, 9, 18, 10, 6, 9, 33, 11, 3],
#  [2, 24, 9, 26, 5, 23, 44, 7, 11, 14, 3],
#  [2, 13, 22, 11, 10, 12, 23, 3],
#  [2, 8, 9, 36, 6, 8, 16, 3],
#  [2, 10, 35, 4, 19, 52, 3],
#  [2, 10, 4, 5, 6, 8, 9, 28, 5, 11, 3],
#  [2, 8, 18, 10, 3],
#  [2, 51, 49, 16, 32, 19, 16, 4, 14, 3],
#  [2, 17, 56, 19, 8, 35, 14, 3],
#  [2, 9, 12, 8, 9, 26, 25, 14, 3],
#  [2, 7, 18, 24, 14, 3],
#  [2, 11, 26, 10, 45, 7, 14, 3],
#  [2, 38, 20, 5, 4, 49, 4, 5, 3],
#  [2, 7, 26, 10, 16, 3],
#  [2, 7, 34, 5, 24, 16, 3],
#  [2, 19, 18, 10, 4, 13, 3],
#  [2, 6, 19, 42, 7, 12, 5, 3],
#  [2, 7, 12, 13, 5, 20, 7, 4, 38, 16, 3],
#  [2, 13, 42, 10, 4, 7, 3],
#  [2, 11, 12, 7, 22, 25, 9, 4, 5, 6, 3],
#  [2, 11, 12, 17, 20, 10, 52, 3],
#  [2, 6, 10, 30, 20, 17, 4, 7, 14, 3],
#  [2, 17, 22, 7, 33, 3],
#  [2, 23, 9, 26, 10, 30, 4, 5, 8, 7, 16, 3],
#  [2, 9, 21, 13, 14, 16, 3],
#  [2, 29, 36, 5, 16, 13, 60, 5, 14, 3],
#  [2, 5, 22, 8, 10, 4, 3],
#  [2, 11, 35, 7, 8, 52, 5, 3],
#  [2, 19, 54, 41, 26, 5, 16, 3],
#  [2, 23, 28, 14, 4, 14, 3],
#  [2, 43, 5, 8, 15, 13, 22, 27, 24, 4, 7, 12, 27, 3],
#  [2, 43, 7, 21, 7, 4, 6, 12, 6, 3],
#  [2, 30, 34, 7, 23, 15, 11, 3],
#  [2, 10, 34, 9, 4, 5, 3],
#  [2, 17, 7, 18, 14, 3],
#  [2, 6, 8, 9, 32, 7, 15, 14, 3],
#  [2, 7, 40, 23, 20, 9, 38, 3],
#  [2, 24, 35, 10, 4, 5, 3],
#  [2, 30, 22, 7, 39, 4, 13, 14, 3],
#  [2, 9, 21, 24, 3],
#  [2, 39, 20, 6, 50, 10, 3],
#  [2, 18, 23, 9, 4, 5, 3],
#  [2, 17, 9, 18, 14, 5, 50, 23, 3],
#  [2, 17, 60, 24, 48, 5, 25, 22, 7, 16, 4, 3],
#  [2, 36, 19, 30, 15, 11, 14, 3],
#  [2, 7, 22, 5, 12, 17, 58, 3],
#  [2, 6, 26, 7, 6, 10, 16, 3],
#  [2, 41, 44, 10, 4, 39, 18, 30, 6, 10, 16, 3],
#  [2, 13, 68, 9, 16, 29, 57, 9, 33, 3],
#  [2, 29, 20, 7, 16, 14, 3],
#  [2, 6, 13, 36, 66, 15, 3],
#  [2, 10, 15, 18, 5, 6, 16, 14, 3],
#  [2, 17, 12, 38, 18, 7, 38, 16, 5, 4, 3],
#  [2, 17, 7, 22, 41, 3],
#  [2, 10, 34, 7, 3],
#  [2, 13, 28, 7, 9, 60, 13, 14, 3],
#  [2, 55, 11, 26, 5, 33, 3],
#  [2, 6, 10, 30, 42, 13, 3],
#  [2, 9, 26, 14, 3],
#  [2, 18, 9, 4, 5, 3],
#  [2, 23, 34, 7, 30, 44, 7, 3],
#  [2, 17, 42, 24, 13, 4, 5, 3],
#  [2, 29, 18, 6, 4, 7, 15, 3],
#  [2, 6, 18, 23, 6, 12, 10, 3],
#  [2, 10, 36, 7, 13, 12, 5, 48, 8, 6, 3],
#  [2, 13, 21, 5, 9, 16, 3],
#  [2, 6, 42, 23, 12, 5, 3],
#  [2, 33, 13, 34, 9, 16, 3],
#  [2, 13, 21, 29, 69, 58, 7, 11, 3],
#  [2, 40, 13, 20, 8, 52, 14, 3],
#  [2, 10, 52, 40, 9, 8, 22, 10, 39, 54, 7, 63, 31, 4, 5, 3],
#  [2, 39, 36, 27, 11, 47, 7, 3],
#  [2, 31, 30, 35, 8, 6, 15, 3],
#  [2, 29, 18, 5, 9, 12, 10, 4, 3],
#  [2, 8, 28, 7, 14, 3],
#  [2, 39, 37, 5, 4, 10, 45, 7, 14, 3],
#  [2, 11, 28, 8, 4, 17, 48, 6, 12, 14, 3],
#  [2, 43, 24, 5, 20, 6, 16, 33, 3],
#  [2, 9, 16, 5, 28, 13, 3],
#  [2, 29, 21, 27, 10, 16, 3],
#  [2, 11, 18, 7, 15, 16, 3],
#  [2, 11, 34, 9, 23, 3],
#  [2, 10, 9, 22, 6, 8, 16, 3],
#  [2, 13, 53, 5, 8, 4, 5, 14, 3],
#  [2, 4, 17, 39, 37, 14, 12, 14, 3],
#  [2, 8, 35, 7, 15, 3],
#  [2, 41, 28, 5, 12, 27, 3],
#  [2, 9, 18, 9, 12, 24, 3],
#  [2, 12, 10, 6, 22, 67, 4, 5, 3],
#  [2, 8, 9, 28, 11, 13, 47, 9, 10, 8, 3],
#  [2, 21, 23, 15, 43, 14, 4, 13, 14, 3],
#  [2, 6, 37, 19, 15, 14, 3],
#  [2, 13, 40, 27, 24, 40, 5, 16, 18, 7, 33, 3],
#  [2, 8, 9, 4, 6, 10, 7, 18, 9, 3],
#  [2, 11, 16, 10, 21, 19, 4, 8, 48, 8, 3],
#  [2, 16, 10, 7, 22, 19, 6, 12, 27, 3],
#  [2, 8, 26, 6, 19, 60, 5, 23, 4, 7, 3],
#  [2, 7, 35, 8, 15, 3],
#  [2, 39, 33, 23, 9, 16, 34, 5, 3],
#  [2, 21, 11, 33, 7, 23, 6, 4, 5, 3],
#  [2, 21, 7, 4, 6, 4, 5, 3],
#  [2, 21, 11, 12, 8, 12, 25, 14, 3],
#  [2, 13, 44, 8, 4, 13, 34, 9, 23, 33, 14, 3],
#  [2, 7, 4, 8, 22, 31, 4, 3],
#  [2, 29, 20, 31, 13, 16, 3],
#  [2, 33, 24, 9, 28, 11, 16, 3],
#  [2, 10, 7, 26, 25, 3],
#  [2, 13, 21, 5, 7, 16, 3],
#  [2, 38, 26, 26, 28, 6, 26, 3],
#  [2, 13, 36, 7, 12, 10, 4, 5, 3],
#  [2, 6, 34, 6, 15, 3],
#  [2, 29, 53, 6, 7, 15, 3],
#  [2, 30, 18, 5, 11, 15, 14, 3],
#  [2, 35, 6, 4, 6, 3],
#  [2, 19, 22, 13, 19, 4, 7, 3],
#  [2, 6, 22, 7, 3],
#  [2, 7, 16, 21, 5, 3],
#  [2, 9, 18, 13, 4, 5, 3],
#  [2, 7, 35, 25, 7, 51, 4, 6, 8, 3],
#  [2, 10, 20, 8, 16, 15, 3],
#  [2, 13, 4, 24, 7, 21, 6, 4, 5, 3],
#  [2, 29, 37, 8, 4, 5, 3],
#  [2, 6, 8, 20, 9, 10, 15, 3],
#  [2, 10, 21, 6, 4, 7, 52, 11, 14, 3],
#  [2, 10, 21, 25, 16, 47, 9, 14, 3],
#  [2, 19, 62, 5, 8, 12, 27, 7, 16, 3],
#  [2, 24, 34, 5, 8, 7, 4, 8, 3],
#  [2, 17, 7, 28, 13, 11, 3],
#  [2, 24, 32, 7, 8, 6, 3],
#  [2, 10, 7, 22, 23, 8, 4, 5, 3],
#  [2, 10, 7, 42, 10, 6, 3],
#  [2, 6, 46, 11, 15, 34, 24, 9, 4, 23, 15, 3],
#  [2, 23, 22, 5, 7, 4, 5, 11, 14, 3],
#  [2, 8, 9, 26, 52, 14, 3],
#  [2, 10, 20, 7, 25, 16, 3],
#  [2, 19, 40, 5, 8, 18, 7, 3],
#  [2, 43, 5, 8, 44, 9, 4, 24, 28, 31, 4, 5, 14, 3],
#  [2, 21, 5, 4, 5, 3],
#  [2, 8, 34, 23, 7, 15, 3],
#  [2, 7, 34, 27, 23, 44, 7, 33, 3],
#  [2, 10, 7, 21, 5, 3],
#  [2, 24, 39, 32, 8, 4, 5, 3],
#  [2, 13, 22, 9, 33, 3],
#  [2, 5, 32, 11, 4, 3],
#  [2, 23, 26, 24, 15, 3],
#  [2, 17, 36, 6, 8, 15, 3],
#  [2, 43, 5, 8, 15, 13, 26, 11, 16, 44, 9, 16, 14, 3],
#  [2, 9, 37, 17, 4, 5, 14, 3],
#  [2, 13, 34, 9, 24, 12, 38, 12, 14, 3],
#  [2, 23, 35, 15, 17, 47, 13, 12, 27, 3],
#  [2, 41, 15, 40, 13, 18, 7, 4, 3],
#  [2, 43, 14, 9, 28, 7, 16, 3],
#  [2, 11, 12, 6, 19, 9, 37, 25, 11, 3],
#  [2, 8, 52, 8, 45, 7, 4, 8, 18, 9, 16, 4, 5, 43, 14, 4, 13, 3],
#  [2, 25, 22, 67, 30, 4, 7, 46, 14, 11, 3],
#  [2, 6, 13, 22, 7, 38, 12, 14, 3],
#  [2, 23, 15, 5, 4, 5, 11, 26, 5, 4, 3],
#  [2, 19, 15, 35, 4, 14, 3],
#  [2, 24, 32, 8, 6, 10, 16, 3],
#  [2, 43, 5, 21, 10, 8, 6, 3],
#  [2, 29, 42, 13, 3],
#  [2, 25, 56, 5, 13, 26, 8, 15, 3],
#  [2, 52, 25, 15, 50, 10, 6, 35, 8, 12, 27, 3],
#  [2, 11, 12, 13, 26, 5, 14, 3],
#  [2, 7, 20, 9, 4, 3],
#  [2, 6, 8, 22, 10, 6, 3],
#  [2, 24, 20, 11, 23, 9, 16, 14, 3],
#  [2, 10, 53, 5, 8, 15, 17, 45, 7, 4, 5, 6, 3],
#  [2, 17, 18, 5, 12, 6, 3],
#  [2, 10, 7, 34, 9, 11, 48, 5, 3],
#  [2, 31, 18, 19, 15, 11, 3],
#  [2, 6, 8, 20, 9, 25, 12, 27, 3],
#  [2, 17, 30, 40, 25, 42, 8, 3],
#  [2, 53, 8, 11, 22, 6, 8, 4, 5, 6, 12, 14, 3],
#  [2, 17, 9, 32, 3],
#  [2, 61, 5, 12, 10, 6, 19, 35, 15, 11, 3],
#  [2, 11, 4, 17, 22, 8, 6, 10, 16, 3],
#  [2, 9, 20, 10, 12, 27, 29, 45, 13, 3],
#  [2, 31, 20, 9, 13, 3],
#  [2, 17, 26, 5, 14, 3],
#  [2, 19, 62, 5, 8, 15, 3],
#  [2, 9, 12, 10, 20, 9, 11, 33, 3],
#  [2, 10, 20, 5, 8, 9, 56, 10, 8, 12, 27, 3],
#  [2, 10, 7, 22, 27, 24, 7, 15, 3],
#  [2, 25, 15, 41, 54, 32, 6, 33, 3],
#  [2, 17, 32, 5, 3],
#  [2, 6, 19, 9, 32, 7, 14, 3],
#  [2, 30, 22, 8, 5, 16, 14, 3],
#  [2, 8, 20, 49, 3],
#  [2, 10, 47, 9, 37, 17, 4, 3],
#  [2, 7, 18, 8, 15, 12, 27, 3],
#  [2, 19, 26, 41, 4, 14, 3],
#  [2, 5, 18, 24, 4, 5, 8, 3],
#  [2, 7, 33, 6, 10, 20, 7, 14, 33, 3],
#  [2, 10, 20, 7, 4, 13, 14, 3],
#  [2, 29, 20, 7, 13, 47, 9, 10, 3],
#  [2, 23, 35, 5, 4, 7, 46, 14, 11, 3],
#  [2, 11, 20, 9, 17, 4, 5, 3],
#  [2, 10, 4, 7, 35, 11, 4, 3],
#  [2, 17, 21, 5, 3],
#  [2, 10, 7, 32, 10, 5, 15, 3],
#  [2, 9, 40, 5, 41, 18, 9, 4, 3],
#  [2, 14, 4, 7, 37, 6, 10, 16, 3],
#  [2, 6, 12, 10, 37, 7, 4, 3],
#  [2, 6, 21, 10, 3],
#  [2, 6, 22, 11, 3],
#  [2, 7, 36, 11, 7, 4, 13, 14, 3],
#  [2, 32, 31, 4, 7, 3],
#  [2, 9, 18, 6, 8, 15, 3],
#  [2, 6, 7, 21, 25, 12, 5, 3],
#  [2, 24, 9, 26, 5, 14, 3],
#  [2, 6, 34, 23, 8, 43, 13, 12, 38, 3],
#  [2, 21, 10, 39, 54, 8, 48, 5, 3],
#  [2, 9, 32, 6, 7, 15, 3],
#  [2, 6, 8, 32, 5, 17, 15, 24, 15, 3],
#  [2, 13, 21, 10, 4, 23, 51, 3],
#  [2, 13, 20, 9, 10, 4, 11, 7, 16, 3],
#  [2, 11, 9, 21, 24, 4, 5, 29, 44, 11, 3],
#  [2, 6, 8, 18, 9, 10, 48, 6, 3],
#  [2, 10, 18, 5, 3],
#  [2, 29, 20, 15, 12, 27, 3],
#  [2, 24, 20, 7, 3],
#  [2, 23, 50, 5, 23, 7, 57, 9, 4, 13, 16, 5, 3],
#  [2, 38, 45, 7, 4, 19, 26, 5, 33, 3],
#  [2, 7, 35, 6, 40, 8, 3],
#  [2, 11, 12, 23, 9, 28, 5, 3],
#  [2, 11, 12, 23, 18, 10, 8, 15, 3],
#  [2, 9, 32, 6, 10, 33, 14, 3],
#  [2, 13, 26, 5, 4, 6, 3],
#  [2, 23, 22, 14, 4, 7, 12, 27, 3],
#  [2, 45, 13, 23, 4, 23, 22, 7, 12, 10, 3],
#  [2, 13, 21, 7, 9, 46, 8, 6, 3],
#  [2, 17, 21, 17, 12, 8, 3],
#  [2, 10, 4, 7, 18, 10, 8, 4, 17, 4, 7, 14, 3],
#  [2, 23, 12, 7, 21, 5, 49, 9, 4, 19, 16, 3],
#  [2, 5, 4, 10, 9, 34, 7, 4, 38, 12, 6, 8, 6, 3],
#  [2, 8, 9, 34, 13, 4, 8, 46, 14, 3],
#  [2, 17, 9, 35, 11, 14, 13, 48, 11, 14, 3],
#  [2, 18, 10, 6, 19, 16, 48, 8, 3],
#  [2, 30, 35, 11, 4, 5, 14, 3],
#  [2, 10, 7, 18, 19, 3],
#  [2, 29, 26, 9, 3],
#  [2, 5, 35, 8, 9, 48, 8, 3],
#  [2, 10, 42, 31, 23, 12, 27, 10, 3],
#  [2, 23, 34, 7, 14, 3],
#  [2, 23, 20, 9, 4, 5, 15, 3],
#  [2, 17, 7, 21, 10, 6, 17, 15, 24, 3],
#  [2, 6, 18, 7, 23, 9, 12, 38, 3],
#  [2, 24, 9, 35, 13, 4, 5, 3],
#  [2, 29, 37, 23, 3],
#  [2, 29, 30, 35, 8, 29, 55, 9, 5, 3],
#  [2, 11, 28, 6, 4, 10, 16, 3],
#  [2, 20, 9, 41, 15, 16, 3],
#  [2, 28, 14, 12, 27, 15, 3],
#  [2, 13, 18, 8, 4, 24, 55, 24, 3],
#  [2, 9, 36, 6, 33, 3],
#  [2, 6, 18, 19, 4, 9, 48, 8, 15, 3],
#  [2, 8, 33, 13, 40, 6, 26, 5, 16, 3],
#  [2, 24, 9, 4, 24, 18, 9, 16, 4, 6, 3],
#  [2, 30, 34, 7, 8, 3],
#  [2, 23, 42, 5, 12, 31, 3],
#  [2, 31, 18, 5, 11, 4, 7, 3],
#  [2, 19, 22, 7, 15, 14, 3],
#  [2, 6, 4, 19, 9, 18, 31, 4, 5, 3],
#  [2, 11, 9, 32, 5, 16, 3],
#  [2, 6, 22, 7, 4, 10, 52, 5, 14, 3],
#  [2, 11, 4, 17, 22, 7, 4, 8, 16, 3],
#  [2, 38, 26, 30, 48, 3],
#  [2, 5, 26, 10, 33, 14, 3],
#  [2, 8, 45, 17, 39, 4, 7, 28, 31, 4, 5, 14, 3],
#  [2, 6, 37, 3],
#  [2, 6, 12, 8, 18, 5, 6, 10, 16, 3],
#  [2, 9, 21, 8, 6, 3],
#  [2, 17, 9, 22, 41, 15, 3],
#  [2, 7, 21, 17, 14, 3],
#  [2, 6, 21, 27, 10, 31, 4, 5, 11, 3],
#  [2, 17, 20, 49, 9, 60, 13, 14, 3],
#  [2, 31, 47, 9, 36, 13, 3],
#  [2, 4, 30, 20, 11, 3],
#  [2, 23, 34, 9, 11, 59, 6, 3],
#  [2, 64, 8, 19, 15, 23, 34, 9, 13, 4, 5, 6, 3],
#  [2, 7, 18, 10, 7, 16, 14, 3],
#  [2, 20, 9, 14, 3],
#  [2, 36, 5, 9, 26, 11, 4, 17, 4, 7, 3],
#  [2, 10, 4, 5, 18, 10, 8, 15, 14, 3],
#  [2, 8, 30, 26, 8, 4, 5, 3],
#  [2, 14, 18, 7, 25, 12, 5, 3],
#  [2, 19, 21, 6, 10, 3],
#  [2, 13, 22, 31, 10, 4, 3],
#  [2, 19, 26, 10, 6, 3],
#  [2, 41, 20, 3],
#  [2, 10, 21, 9, 4, 7, 3],
#  [2, 10, 53, 7, 6, 4, 5, 3],
#  [2, 23, 22, 5, 4, 10, 63, 5, 3],
#  [2, 31, 21, 8, 15, 19, 9, 60, 23, 3],
#  [2, 12, 5, 6, 46, 10, 7, 33, 19, 26, 11, 16, 4, 3],
#  [2, 6, 42, 10, 4, 13, 6, 8, 45, 5, 6, 12, 14, 3],
#  [2, 6, 22, 9, 16, 3],
#  [2, 24, 40, 13, 18, 14, 3],
#  [2, 23, 9, 26, 11, 13, 4, 5, 3],
#  [2, 6, 8, 20, 8, 6, 3],
#  [2, 31, 21, 5, 11, 30, 43, 10, 3],
#  [2, 8, 26, 8, 4, 5, 14, 3],
#  [2, 11, 12, 17, 15, 5, 20, 9, 11, 16, 3],
#  [2, 24, 40, 7, 37, 14, 33, 3],
#  [2, 11, 9, 60, 18, 7, 4, 3],
#  [2, 38, 37, 5, 4, 8, 3],
#  [2, 10, 21, 13, 19, 12, 27, 3],
#  [2, 9, 26, 6, 5, 15, 3],
#  [2, 9, 12, 6, 26, 8, 6, 3],
#  [2, 10, 42, 10, 13, 4, 5, 3],
#  [2, 13, 21, 5, 8, 59, 3],
#  [2, 6, 8, 37, 19, 15, 3],
#  [2, 11, 18, 13, 10, 33, 3],
#  [2, 17, 26, 5, 17, 7, 4, 6, 4, 13, 3],
#  [2, 7, 4, 23, 20, 25, 3],
#  [2, 33, 17, 42, 5, 3],
#  [2, 6, 19, 26, 11, 16, 15, 3],
#  [2, 23, 28, 14, 3],
#  [2, 10, 30, 18, 6, 41, 4, 5, 15, 3],
#  [2, 35, 40, 13, 14, 3],
#  [2, 36, 19, 8, 48, 10, 3],
#  [2, 5, 40, 9, 41, 26, 6, 33, 3],
#  [2, 24, 20, 14, 4, 5, 14, 3],
#  [2, 13, 20, 9, 49, 4, 7, 15, 3],
#  [2, 25, 56, 5, 30, 22, 9, 4, 5, 3],
#  [2, 23, 42, 17, 16, 3],
#  [2, 13, 4, 10, 34, 14, 7, 4, 5, 3],
#  [2, 19, 26, 9, 6, 4, 5, 3],
#  [2, 43, 7, 37, 13, 4, 5, 48, 8, 6, 3],
#  [2, 6, 19, 21, 5, 39, 4, 7, 3],
#  [2, 19, 18, 27, 24, 45, 6, 4, 5, 3],
#  [2, 29, 21, 5, 17, 33, 3],
#  [2, 23, 9, 21, 27, 10, 4, 25, 12, 41, 3],
#  [2, 24, 9, 26, 5, 7, 51, 23, 3],
#  [2, 6, 18, 7, 13, 4, 5, 3],
#  [2, 13, 4, 10, 39, 37, 4, 5, 3],
#  [2, 6, 8, 20, 9, 10, 3],
#  [2, 9, 26, 31, 3],
#  [2, 7, 18, 5, 29, 47, 9, 8, 3],
#  [2, 12, 13, 32, 31, 4, 5, 4, 7, 3],
#  [2, 11, 26, 6, 4, 5, 8, 7, 16, 3],
#  [2, 17, 9, 28, 7, 3],
#  [2, 13, 42, 11, 4, 5, 3],
#  [2, 24, 34, 14, 3],
#  [2, 13, 12, 7, 22, 31, 4, 3],
#  [2, 5, 35, 5, 15, 14, 3],
#  [2, 29, 57, 11, 12, 11, 3],
#  [2, 13, 40, 9, 10, 18, 7, 3],
#  [2, 6, 19, 20, 8, 7, 46, 8, 12, 11, 3],
#  [2, 17, 21, 24, 31, 55, 3],
#  [2, 24, 22, 23, 16, 3],
#  [2, 8, 26, 8, 15, 11, 3],
#  [2, 17, 60, 8, 4, 7, 28, 14, 16, 3],
#  [2, 19, 21, 5, 12, 10, 3],
#  [2, 11, 12, 6, 8, 9, 18, 6, 3],
#  [2, 21, 24, 7, 15, 3],
#  [2, 6, 10, 18, 19, 8, 12, 10, 4, 7, 3],
#  [2, 11, 21, 5, 6, 15, 3],
#  [2, 6, 19, 18, 9, 4, 3],
#  [2, 23, 18, 8, 5, 15, 3],
#  [2, 18, 10, 6, 23, 35, 8, 15, 3],
#  [2, 9, 21, 19, 8, 3],
#  [2, 18, 13, 19, 8, 16, 12, 27, 3],
#  [2, 19, 57, 7, 3],
#  [2, 18, 13, 7, 12, 27, 3],
#  [2, 5, 37, 10, 3],
#  [2, 9, 12, 14, 42, 25, 14, 3],
#  [2, 7, 54, 32, 27, 24, 33, 3],
#  [2, 17, 48, 8, 4, 6, 18, 9, 47, 5, 3],
#  [2, 29, 20, 7, 13, 4, 5, 3],
#  [2, 13, 40, 5, 14, 16, 32, 5, 16, 3],
#  [2, 22, 5, 7, 4, 5, 11, 14, 3],
#  [2, 11, 12, 6, 8, 22, 7, 15, 16, 3],
#  [2, 14, 18, 3],
#  [2, 35, 15, 5, 46, 14, 11, 3],
#  [2, 17, 36, 24, 46, 11, 3],
#  [2, 7, 63, 25, 20, 9, 16, 33, 3],
#  [2, 10, 9, 12, 6, 21, 5, 49, 4, 13, 4, 13, 3],
#  [2, 13, 40, 9, 41, 16, 20, 5, 33, 3],
#  [2, 8, 4, 13, 20, 9, 52, 14, 3],
#  [2, 11, 4, 38, 34, 27, 3],
#  [2, 21, 10, 8, 6, 3],
#  [2, 38, 26, 19, 5, 16, 3],
#  [2, 13, 12, 10, 26, 11, 54, 3],
#  [2, 17, 21, 17, 4, 7, 12, 27, 3],
#  [2, 6, 20, 9, 10, 45, 14, 4, 13, 3],
#  [2, 11, 18, 5, 16, 14, 3],
#  [2, 6, 22, 7, 10, 30, 65, 13, 14, 3],
#  [2, 6, 26, 24, 13, 4, 5, 11, 3],
#  [2, 5, 21, 19, 3],
#  [2, 17, 22, 7, 39, 4, 5, 49, 3],
#  [2, 34, 6, 10, 4, 7, 4, 6, 3],
#  [2, 19, 21, 8, 12, 5, 3],
#  [2, 49, 22, 24, 19, 4, 5, 3],
#  [2, 8, 30, 22, 27, 10, 3],
#  [2, 25, 32, 7, 10, 13, 15, 3],
#  [2, 8, 20, 13, 10, 12, 5, 14, 3],
#  [2, 17, 7, 21, 10, 5, 16, 3],
#  [2, 40, 10, 16, 39, 20, 13, 4, 3],
#  [2, 13, 20, 9, 11, 16, 3],
#  [2, 23, 7, 36, 8, 15, 11, 3],
#  [2, 21, 7, 10, 47, 8, 3],
#  [2, 32, 5, 3],
#  [2, 30, 35, 9, 8, 45, 19, 6, 3],
#  [2, 29, 20, 9, 10, 9, 4, 11, 15, 3],
#  [2, 13, 18, 9, 16, 13, 64, 5, 8, 3],
#  [2, 4, 19, 26, 7, 4, 17, 4, 7, 3],
#  [2, 23, 22, 31, 13, 47, 27, 24, 15, 3],
#  [2, 17, 34, 6, 13, 4, 5, 3],
#  [2, 17, 20, 9, 5, 6, 8, 55, 9, 13, 3],
#  [2, 43, 5, 6, 22, 6, 8, 12, 27, 3],
#  [2, 56, 8, 7, 21, 5, 8, 12, 6, 12, 14, 3],
#  [2, 8, 9, 21, 29, 15, 5, 3],
#  [2, 19, 42, 11, 4, 5, 3],
#  [2, 6, 4, 17, 6, 10, 9, 35, 17, 14, 3],
#  [2, 29, 26, 9, 33, 46, 14, 11, 3],
#  [2, 6, 61, 17, 29, 39, 37, 13, 4, 5, 3],
#  [2, 17, 18, 7, 38, 4, 5, 14, 3],
#  [2, 19, 9, 22, 41, 12, 8, 3],
#  [2, 10, 4, 13, 19, 18, 7, 12, 27, 3],
#  [2, 18, 7, 6, 3],
#  [2, 41, 22, 6, 4, 7, 15, 3],
#  [2, 41, 26, 8, 12, 11, 3],
#  [2, 17, 9, 22, 10, 29, 64, 6, 3],
#  [2, 6, 19, 35, 8, 3],
#  [2, 19, 22, 10, 4, 5, 11, 14, 3],
#  [2, 17, 9, 30, 16, 7, 18, 8, 3],
#  [2, 30, 36, 5, 11, 15, 7, 16, 3],
#  [2, 30, 42, 10, 13, 59, 6, 8, 15, 3],
#  [2, 11, 12, 6, 26, 6, 8, 3],
#  [2, 6, 32, 7, 25, 12, 24, 3],
#  [2, 10, 37, 24, 7, 15, 3],
#  [2, 22, 9, 4, 24, 48, 8, 12, 11, 3],
#  [2, 13, 4, 5, 35, 4, 10, 4, 7, 3],
#  [2, 31, 18, 29, 15, 5, 3],
#  [2, 6, 21, 7, 39, 40, 9, 11, 14, 3],
#  [2, 5, 32, 8, 19, 45, 11, 3],
#  [2, 24, 18, 5, 6, 4, 7, 3],
#  [2, 24, 9, 20, 17, 7, 15, 3],
#  [2, 10, 7, 37, 38, 3],
#  [2, 20, 9, 17, 4, 8, 9, 44, 9, 16, 3],
#  [2, 14, 22, 27, 10, 3],
#  [2, 29, 53, 14, 4, 5, 3],
#  [2, 17, 16, 6, 26, 41, 12, 27, 3],
#  [2, 6, 10, 22, 17, 3],
#  [2, 39, 60, 6, 42, 19, 3],
#  [2, 13, 4, 10, 5, 26, 7, 16, 3],
#  [2, 6, 8, 20, 7, 3],
#  [2, 31, 22, 13, 19, 23, 3],
#  [2, 18, 10, 33, 12, 27, 3],
#  [2, 6, 4, 17, 38, 18, 10, 8, 6, 3],
#  [2, 9, 16, 6, 34, 9, 8, 12, 27, 3],
#  [2, 6, 8, 35, 9, 4, 23, 52, 13, 3],
#  [2, 43, 13, 39, 54, 5, 4, 14, 28, 31, 4, 5, 3],
#  [2, 10, 33, 29, 26, 67, 4, 5, 3],
#  [2, 10, 30, 34, 9, 8, 15, 11, 44, 10, 3],
#  [2, 5, 53, 4, 7, 14, 3],
#  [2, 29, 12, 6, 19, 21, 5, 12, 10, 6, 3],
#  [2, 25, 62, 8, 10, 33, 3],
#  [2, 18, 49, 12, 6, 12, 6, 8, 6, 3],
#  [2, 10, 21, 14, 7, 69, 6, 10, 4, 14, 3],
#  [2, 19, 4, 8, 18, 5, 31, 4, 7, 3],
#  [2, 22, 24, 5, 15, 4, 5, 8, 3],
#  [2, 10, 20, 5, 6, 4, 7, 14, 3],
#  [2, 5, 32, 8, 12, 10, 3],
#  [2, 38, 18, 19, 6, 4, 5, 3],
#  [2, 17, 12, 10, 36, 14, 3],
#  [2, 17, 9, 21, 6, 3],
#  [2, 17, 40, 11, 57, 9, 4, 3],
#  [2, 23, 7, 21, 8, 29, 44, 11, 3],
#  [2, 6, 10, 9, 20, 10, 16, 3],
#  [2, 19, 4, 5, 18, 8, 4, 14, 3],
#  [2, 17, 22, 5, 4, 13, 3],
#  [2, 10, 20, 7, 3],
#  [2, 19, 9, 35, 6, 12, 14, 3],
#  [2, 17, 18, 7, 11, 12, 27, 3],
#  [2, 8, 20, 10, 6, 4, 5, 3],
#  [2, 19, 18, 9, 4, 8, 16, 14, 3],
#  [2, 6, 19, 20, 9, 8, 4, 5, 14, 3],
#  [2, 5, 20, 9, 7, 12, 27, 3],
#  [2, 10, 9, 21, 23, 8, 30, 15, 10, 3],
#  [2, 23, 34, 9, 12, 6, 8, 3],
#  [2, 13, 47, 11, 15, 5, 59, 14, 28, 31, 4, 3],
#  [2, 17, 34, 7, 10, 7, 4, 17, 3],
#  [2, 10, 4, 5, 38, 18, 10, 31, 15, 3],
#  [2, 11, 28, 5, 3],
#  [2, 20, 9, 5, 6, 8, 3],
#  [2, 33, 17, 9, 35, 4, 5, 3],
#  [2, 24, 45, 27, 24, 7, 16, 20, 5, 12, 10, 3],
#  [2, 41, 28, 5, 38, 4, 17, 4, 7, 3],
#  [2, 11, 12, 6, 19, 18, 9, 4, 8, 16, 14, 3],
#  [2, 6, 21, 13, 19, 6, 4, 7, 3],
#  [2, 29, 36, 14, 17, 4, 5, 11, 14, 3],
#  [2, 4, 17, 18, 8, 12, 27, 3],
#  [2, 23, 21, 7, 10, 4, 5, 15, 14, 3],
#  [2, 13, 4, 10, 34, 7, 4, 5, 3],
#  [2, 13, 4, 7, 18, 10, 39, 4, 7, 15, 3],
#  [2, 25, 18, 5, 12, 13, 4, 3],
#  [2, 39, 58, 9, 11, 21, 5, 4, 3],
#  [2, 19, 20, 10, 63, 8, 3],
#  [2, 21, 24, 56, 41, 3],
#  [2, 18, 27, 13, 4, 5, 3],
#  [2, 39, 47, 6, 54, 29, 26, 10, 33, 3],
#  [2, 7, 28, 55, 23, 3],
#  [2, 13, 18, 6, 16, 3],
#  [2, 9, 20, 17, 15, 16, 14, 3],
#  [2, 6, 53, 49, 43, 5, 3],
#  [2, 6, 19, 40, 11, 40, 41, 26, 5, 16, 3],
#  [2, 21, 13, 4, 5, 3],
#  [2, 9, 32, 41, 17, 15, 24, 3],
#  [2, 31, 21, 13, 17, 33, 3],
#  [2, 22, 13, 4, 8, 48, 8, 15, 3],
#  ...]

# %%
print("word: ", words[10000])
print("word Sequence: ",ch_sequences[10000])
# Out:
# word:  reelection
# word Sequence:  [4, 2, 2, 10, 2, 11, 9, 5, 8, 7]

# %%
print("Phoneme: ", phonemes[10000])
print("Phonic Sequence: ",ph_sequences[10000])
# Out:
# Phoneme:  startseq R IY0 IH0 L EH1 K SH AH0 N endseq
# Phonic Sequence:  [2, 9, 16, 12, 7, 18, 10, 31, 4, 5, 3]

# %% [markdown]
# ### 3. Decoder input-output generation for teacher forcing

# %%
decoder_inputs = []
decoder_outputs = []

for ph in ph_sequences:
    decoder_inputs.append(ph[:-1])
    decoder_outputs.append(ph[1:])

print(decoder_inputs)
print(decoder_outputs)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### 4. Padding all sequences

# %%
encoder_inputs = pad_sequences(ch_sequences, maxlen=max_len_ip, padding='post')

decoder_inputs = pad_sequences(decoder_inputs, maxlen=max_len_op, padding='post')
decoder_outputs = pad_sequences(decoder_outputs, maxlen=max_len_op, padding='post')

# %%
len(decoder_inputs)
# Out:
# 100000

# %% [markdown]
# ### Training-Validation splitting

# %%
n = len(words)
split_index = int(0.85 * n)
print('length of training dataset:', split_index)
print('length of validation dataset:', n-split_index)
# Out:
# length of training dataset: 85000
# length of validation dataset: 15000

# %%
X_train = [encoder_inputs[:split_index], decoder_inputs[:split_index]]
y_train = decoder_outputs[:split_index]

X_test = words[split_index:]
y_test = phonemes[split_index:]

# %%
len(X_train[0])
# Out:
# 85000

# %%
X_train[0].shape
# Out:
# (85000, 28)

# %%
X_train[1].shape
# Out:
# (85000, 30)

# %%
y_train.shape
# Out:
# (85000, 30)

# %% [markdown]
# # Model Building

# %% [markdown]
# Model 1

# %%
# Encoder
char_input = Input(shape=(None,))
x = Embedding(char_vocab_size, 128, mask_zero=True)(char_input)
output_y, state_h, state_c = LSTM(128, return_state=True)(x)

# Decoder
ph_input = Input(shape=(None,))
embedding_layer = Embedding(phone_vocab_size, 128, mask_zero=True)
x = embedding_layer(ph_input)
decoder_lstm = LSTM(128, return_sequences=True, return_state=True)
output_y, _ , _ = decoder_lstm(x, initial_state=[state_h, state_c])
softmax_dense = Dense(phone_vocab_size, activation='softmax')
output = softmax_dense(output_y)

model = Model(inputs=[char_input, ph_input],outputs=output)
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_18 (InputLayer)          [(None, None)]       0           []
#
#  input_19 (InputLayer)          [(None, None)]       0           []
#
#  embedding_17 (Embedding)       (None, None, 128)    4608        ['input_18[0][0]']
#
#  embedding_18 (Embedding)       (None, None, 128)    9984        ['input_19[0][0]']
#
#  lstm_19 (LSTM)                 [(None, 128),        131584      ['embedding_17[0][0]']
#                                  (None, 128),
#                                  (None, 128)]
#
#  lstm_20 (LSTM)                 [(None, None, 128),  131584      ['embedding_18[0][0]',
#                                  (None, 128),                     'lstm_19[0][1]',
#                                  (None, 128)]                     'lstm_19[0][2]']
#
#  dense_7 (Dense)                (None, None, 78)     10062       ['lstm_20[0][0]']
#
# ==================================================================================================
# Total params: 287,822
# Trainable params: 287,822
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train,y_train,
                    batch_size=32,
                    epochs=20,
                    validation_split=0.4,
                    validation_batch_size=32)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 49s 22ms/step - loss: 1.8518 - accuracy: 0.5141 - val_loss: 1.0893 - val_accuracy: 0.6987
# Epoch 2/20
# 1594/1594 [==============================] - 29s 18ms/step - loss: 0.8714 - accuracy: 0.7531 - val_loss: 0.7314 - val_accuracy: 0.7888
# Epoch 3/20
# 1594/1594 [==============================] - 27s 17ms/step - loss: 0.6442 - accuracy: 0.8124 - val_loss: 0.5988 - val_accuracy: 0.8253
# Epoch 4/20
# 1594/1594 [==============================] - 27s 17ms/step - loss: 0.5366 - accuracy: 0.8422 - val_loss: 0.5360 - val_accuracy: 0.8425
# Epoch 5/20
# 1594/1594 [==============================] - 33s 20ms/step - loss: 0.4728 - accuracy: 0.8599 - val_loss: 0.4902 - val_accuracy: 0.8554
# Epoch 6/20
# 1594/1594 [==============================] - 32s 20ms/step - loss: 0.4283 - accuracy: 0.8717 - val_loss: 0.4653 - val_accuracy: 0.8615
# Epoch 7/20
# 1594/1594 [==============================] - 28s 18ms/step - loss: 0.3952 - accuracy: 0.8811 - val_loss: 0.4447 - val_accuracy: 0.8669
# Epoch 8/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.3688 - accuracy: 0.8877 - val_loss: 0.4408 - val_accuracy: 0.8688
# Epoch 9/20
# 1594/1594 [==============================] - 33s 21ms/step - loss: 0.3466 - accuracy: 0.8942 - val_loss: 0.4239 - val_accuracy: 0.8733
# Epoch 10/20
# 1594/1594 [==============================] - 27s 17ms/step - loss: 0.3273 - accuracy: 0.8994 - val_loss: 0.4194 - val_accuracy: 0.8748
# Epoch 11/20
# 1594/1594 [==============================] - 28s 18ms/step - loss: 0.3099 - accuracy: 0.9038 - val_loss: 0.4205 - val_accuracy: 0.8750
# Epoch 12/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.2959 - accuracy: 0.9080 - val_loss: 0.4164 - val_accuracy: 0.8763
# Epoch 13/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.2813 - accuracy: 0.9122 - val_loss: 0.4136 - val_accuracy: 0.8778
# Epoch 14/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.2703 - accuracy: 0.9156 - val_loss: 0.4176 - val_accuracy: 0.8776
# Epoch 15/20
# 1594/1594 [==============================] - 30s 19ms/step - loss: 0.2583 - accuracy: 0.9191 - val_loss: 0.4178 - val_accuracy: 0.8781
# Epoch 16/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.2474 - accuracy: 0.9222 - val_loss: 0.4139 - val_accuracy: 0.8788
# Epoch 17/20
# 1594/1594 [==============================] - 32s 20ms/step - loss: 0.2375 - accuracy: 0.9250 - val_loss: 0.4218 - val_accuracy: 0.8781
# Epoch 18/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.2292 - accuracy: 0.9273 - val_loss: 0.4211 - val_accuracy: 0.8796
# Epoch 19/20
# 1594/1594 [==============================] - 27s 17ms/step - loss: 0.2209 - accuracy: 0.9299 - val_loss: 0.4246 - val_accuracy: 0.8794
# Epoch 20/20
# 1594/1594 [==============================] - 28s 18ms/step - loss: 0.2126 - accuracy: 0.9323 - val_loss: 0.4313 - val_accuracy: 0.8787

# %%
history = model.fit(X_train,y_train,
                    batch_size=32,
                    epochs=20,
                    validation_split=0.4,
                    validation_batch_size=32)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 28s 18ms/step - loss: 0.2058 - accuracy: 0.9344 - val_loss: 0.4359 - val_accuracy: 0.8775
# Epoch 2/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.1991 - accuracy: 0.9363 - val_loss: 0.4375 - val_accuracy: 0.8783
# Epoch 3/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.1925 - accuracy: 0.9387 - val_loss: 0.4513 - val_accuracy: 0.8755
# Epoch 4/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.1865 - accuracy: 0.9401 - val_loss: 0.4520 - val_accuracy: 0.8772
# Epoch 5/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.1804 - accuracy: 0.9420 - val_loss: 0.4570 - val_accuracy: 0.8766
# Epoch 6/20
# 1594/1594 [==============================] - 27s 17ms/step - loss: 0.1749 - accuracy: 0.9438 - val_loss: 0.4622 - val_accuracy: 0.8771
# Epoch 7/20
# 1594/1594 [==============================] - 29s 18ms/step - loss: 0.1706 - accuracy: 0.9451 - val_loss: 0.4703 - val_accuracy: 0.8756
# Epoch 8/20
# 1594/1594 [==============================] - 28s 18ms/step - loss: 0.1642 - accuracy: 0.9470 - val_loss: 0.4726 - val_accuracy: 0.8761
# Epoch 9/20
# 1594/1594 [==============================] - 27s 17ms/step - loss: 0.1604 - accuracy: 0.9483 - val_loss: 0.4825 - val_accuracy: 0.8745
# Epoch 10/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.1563 - accuracy: 0.9494 - val_loss: 0.4844 - val_accuracy: 0.8758
# Epoch 11/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.1517 - accuracy: 0.9514 - val_loss: 0.4954 - val_accuracy: 0.8746
# Epoch 12/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 0.1473 - accuracy: 0.9525 - val_loss: 0.4985 - val_accuracy: 0.8737
# Epoch 13/20
# 1594/1594 [==============================] - 32s 20ms/step - loss: 0.1445 - accuracy: 0.9533 - val_loss: 0.5065 - val_accuracy: 0.8731
# Epoch 14/20
# 1592/1594 [============================>.] - ETA: 0s - loss: 0.1411 - accuracy: 0.9541
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-01f932fd16d4> in <module>
# ----> 1 history = model.fit(X_train,y_train,
#       2                     batch_size=32,
#       3                     epochs=20,
#       4                     validation_split=0.4,
#       5                     validation_batch_size=32)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1692                             steps_per_execution=self._steps_per_execution,
#    1693                         )
# -> 1694                     val_logs = self.evaluate(
#    1695                         x=val_x,
#    1696                         y=val_y,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2038                         ):
#    2039                             callbacks.on_test_batch_begin(step)
# -> 2040                             tmp_logs = self.test_function(iterator)
#    2041                             if data_handler.should_sync:
#    2042                                 context.async_wait()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     917       # In this case we have not created variables on the first call. So we can
#     918       # run the first trace but we should fail if variables are created.
# --> 919       results = self._variable_creation_fn(*args, **kwds)
#     920       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     921         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.save_weights('model1.h5')
with open('model1.json', 'w') as f:
  f.write(model.to_json())

# %% [markdown]
# Model 2

# %%
# Encoder
char_input = Input(shape=(None,))
x = Embedding(char_vocab_size, 128, mask_zero=True)(char_input)
x=LSTM(128, return_sequences=True)(x)
output_y, state_h, state_c = LSTM(256, return_state=True)(x)

# Decoder
ph_input = Input(shape=(None,))
embedding_layer = Embedding(phone_vocab_size, 128, mask_zero=True)
x = embedding_layer(ph_input)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
output_y, _ , _ = decoder_lstm(x, initial_state=[state_h, state_c])
softmax_dense = Dense(phone_vocab_size, activation='softmax')
output = softmax_dense(output_y)

model = Model(inputs=[char_input, ph_input],outputs=output)
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_17"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_38 (InputLayer)          [(None, None)]       0           []
#
#  embedding_35 (Embedding)       (None, None, 128)    4736        ['input_38[0][0]']
#
#  input_39 (InputLayer)          [(None, None)]       0           []
#
#  lstm_47 (LSTM)                 (None, None, 128)    131584      ['embedding_35[0][0]']
#
#  embedding_36 (Embedding)       (None, None, 128)    9984        ['input_39[0][0]']
#
#  lstm_48 (LSTM)                 [(None, 256),        394240      ['lstm_47[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_49 (LSTM)                 [(None, None, 256),  394240      ['embedding_36[0][0]',
#                                  (None, 256),                     'lstm_48[0][1]',
#                                  (None, 256)]                     'lstm_48[0][2]']
#
#  dense_15 (Dense)               (None, None, 78)     20046       ['lstm_49[0][0]']
#
# ==================================================================================================
# Total params: 954,830
# Trainable params: 954,830
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.f
# 1594/1594 [==============================] - 38s 24ms/step - loss: 0.0631 - accuracy: 0.9807 - val_loss: 0.4762 - val_accuracy: 0.8902
# Epoch 19/20
# 1594/1594 [==============================] - 39s 25ms/step - loss: 0.0590 - accuracy: 0.9819 - val_loss: 0.4885 - val_accuracy: 0.8895
# Epoch 20/20
# 1594/1594 [==============================] - 43s 27ms/step - loss: 0.0545 - accuracy: 0.9834 - val_loss: 0.5000 - val_accuracy: 0.8895

# %%
model.save_weights('model2.h5')
with open('model2.json', 'w') as f:
  f.write(model.to_json())

# %% [markdown]
# Model 3

# %%
from tensorflow.keras.optimizers import Adam
adam=Adam(learning_rate=0.01)

# %%
char_vocab_size
phone_vocab_size

# Encoder
char_input = Input(shape=(None,))
x = Embedding(char_vocab_size, 256, mask_zero=True)(char_input)
x=LSTM(128, return_sequences=True)(x)
output_y, state_h, state_c = LSTM(256, return_state=True)(x)

# Decoder
ph_input = Input(shape=(None,))
embedding_layer = Embedding(phone_vocab_size, 256, mask_zero=True)
x = embedding_layer(ph_input)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
output_y, _ , _ = decoder_lstm(x, initial_state=[state_h, state_c])
softmax_dense = Dense(phone_vocab_size, activation='softmax')
output = softmax_dense(output_y)

model = Model(inputs=[char_input, ph_input],outputs=output)
model.compile(loss='sparse_categorical_crossentropy',optimizer=adam, metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_24 (InputLayer)          [(None, None)]       0           []
#
#  embedding_23 (Embedding)       (None, None, 256)    9216        ['input_24[0][0]']
#
#  input_25 (InputLayer)          [(None, None)]       0           []
#
#  lstm_27 (LSTM)                 (None, None, 128)    197120      ['embedding_23[0][0]']
#
#  embedding_24 (Embedding)       (None, None, 256)    19968       ['input_25[0][0]']
#
#  lstm_28 (LSTM)                 [(None, 256),        394240      ['lstm_27[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_29 (LSTM)                 [(None, None, 256),  525312      ['embedding_24[0][0]',
#                                  (None, 256),                     'lstm_28[0][1]',
#                                  (None, 256)]                     'lstm_28[0][2]']
#
#  dense_10 (Dense)               (None, None, 78)     20046       ['lstm_29[0][0]']
#
# ==================================================================================================
# Total params: 1,165,902
# Trainable params: 1,165,902
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train,y_train,
                    batch_size=32,
                    epochs=20,
                    validation_split=0.4,
                    validation_batch_size=32)
# Out:
# Epoch 1/20
# 1594/1594 [==============================] - 58s 28ms/step - loss: 0.9787 - accuracy: 0.7242 - val_loss: 0.6184 - val_accuracy: 0.8168
# Epoch 2/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.5665 - accuracy: 0.8315 - val_loss: 0.5562 - val_accuracy: 0.8356
# Epoch 3/20
# 1594/1594 [==============================] - 37s 24ms/step - loss: 0.5266 - accuracy: 0.8421 - val_loss: 0.5389 - val_accuracy: 0.8400
# Epoch 4/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.5095 - accuracy: 0.8477 - val_loss: 0.5406 - val_accuracy: 0.8398
# Epoch 5/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.5055 - accuracy: 0.8480 - val_loss: 0.5340 - val_accuracy: 0.8408
# Epoch 6/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.5033 - accuracy: 0.8485 - val_loss: 0.5143 - val_accuracy: 0.8479
# Epoch 7/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.4830 - accuracy: 0.8543 - val_loss: 0.5248 - val_accuracy: 0.8454
# Epoch 8/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.4881 - accuracy: 0.8528 - val_loss: 0.5286 - val_accuracy: 0.8455
# Epoch 9/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.4867 - accuracy: 0.8530 - val_loss: 0.5303 - val_accuracy: 0.8439
# Epoch 10/20
# 1594/1594 [==============================] - 39s 24ms/step - loss: 0.4839 - accuracy: 0.8544 - val_loss: 0.5178 - val_accuracy: 0.8472
# Epoch 11/20
# 1594/1594 [==============================] - 40s 25ms/step - loss: 0.4799 - accuracy: 0.8553 - val_loss: 0.5038 - val_accuracy: 0.8523
# Epoch 12/20
# 1594/1594 [==============================] - 36s 23ms/step - loss: 0.4735 - accuracy: 0.8571 - val_loss: 0.5125 - val_accuracy: 0.8491
# Epoch 13/20
# 1594/1594 [==============================] - 36s 23ms/step - loss: 0.4710 - accuracy: 0.8577 - val_loss: 0.5102 - val_accuracy: 0.8507
# Epoch 14/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.4771 - accuracy: 0.8564 - val_loss: 0.5290 - val_accuracy: 0.8464
# Epoch 15/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.4846 - accuracy: 0.8540 - val_loss: 0.5178 - val_accuracy: 0.8498
# Epoch 16/20
# 1594/1594 [==============================] - 39s 24ms/step - loss: 0.4748 - accuracy: 0.8566 - val_loss: 0.5240 - val_accuracy: 0.8466
# Epoch 17/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.4779 - accuracy: 0.8563 - val_loss: 0.5075 - val_accuracy: 0.8518
# Epoch 18/20
# 1594/1594 [==============================] - 37s 23ms/step - loss: 0.4745 - accuracy: 0.8569 - val_loss: 0.5169 - val_accuracy: 0.8486
# Epoch 19/20
# 1594/1594 [==============================] - 36s 23ms/step - loss: 0.4817 - accuracy: 0.8554 - val_loss: 0.5237 - val_accuracy: 0.8487
# Epoch 20/20
# 1594/1594 [==============================] - 36s 23ms/step - loss: 0.4731 - accuracy: 0.8579 - val_loss: 0.5167 - val_accuracy: 0.8493

# %%
model.save_weights('model3.h5')
with open('model3.json', 'w') as f:
  f.write(model.to_json())

# %%
char_vocab_size
phone_vocab_size

# Encoder
char_input = Input(shape=(None,))
x = Embedding(char_vocab_size, 256, mask_zero=True)(char_input)
x=LSTM(128, return_sequences=True)(x)
output_y, state_h, state_c = LSTM(256, return_state=True)(x)

# Decoder
ph_input = Input(shape=(None,))
embedding_layer = Embedding(phone_vocab_size, 256, mask_zero=True)
x = embedding_layer(ph_input)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
output_y, _ , _ = decoder_lstm(x, initial_state=[state_h, state_c])
softmax_dense = Dense(phone_vocab_size, activation='softmax')
output = softmax_dense(output_y)

model = Model(inputs=[char_input, ph_input],outputs=output)
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 256)    9472        ['input_3[0][0]']
#
#  input_4 (InputLayer)           [(None, None)]       0           []
#
#  lstm (LSTM)                    (None, None, 128)    197120      ['embedding[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 256)    19712       ['input_4[0][0]']
#
#  lstm_1 (LSTM)                  [(None, 256),        394240      ['lstm[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_2 (LSTM)                  [(None, None, 256),  525312      ['embedding_1[0][0]',
#                                  (None, 256),                     'lstm_1[0][1]',
#                                  (None, 256)]                     'lstm_1[0][2]']
#
#  dense (Dense)                  (None, None, 77)     19789       ['lstm_2[0][0]']
#
# ==================================================================================================
# Total params: 1,165,645
# Trainable params: 1,165,645
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train,y_train,
                    batch_size=16,
                    epochs=20,
                    validation_split=0.4,
                    validation_batch_size=16)
# Out:
# Epoch 1/20
# 3188/3188 [==============================] - 97s 25ms/step - loss: 1.3451 - accuracy: 0.6312 - val_loss: 0.6748 - val_accuracy: 0.8052
# Epoch 2/20
# 3188/3188 [==============================] - 72s 23ms/step - loss: 0.5356 - accuracy: 0.8415 - val_loss: 0.4664 - val_accuracy: 0.8611
# Epoch 3/20
# 3188/3188 [==============================] - 72s 22ms/step - loss: 0.3940 - accuracy: 0.8803 - val_loss: 0.4080 - val_accuracy: 0.8769
# Epoch 4/20
# 3188/3188 [==============================] - 81s 25ms/step - loss: 0.3249 - accuracy: 0.8991 - val_loss: 0.3769 - val_accuracy: 0.8863
# Epoch 5/20
# 3188/3188 [==============================] - 71s 22ms/step - loss: 0.2765 - accuracy: 0.9123 - val_loss: 0.3598 - val_accuracy: 0.8924
# Epoch 6/20
# 3188/3188 [==============================] - 70s 22ms/step - loss: 0.2388 - accuracy: 0.9234 - val_loss: 0.3592 - val_accuracy: 0.8934
# Epoch 7/20
# 3188/3188 [==============================] - 80s 25ms/step - loss: 0.2066 - accuracy: 0.9329 - val_loss: 0.3606 - val_accuracy: 0.8948
# Epoch 8/20
# 3188/3188 [==============================] - 70s 22ms/step - loss: 0.1810 - accuracy: 0.9411 - val_loss: 0.3732 - val_accuracy: 0.8937
# Epoch 9/20
# 3188/3188 [==============================] - 70s 22ms/step - loss: 0.1573 - accuracy: 0.9481 - val_loss: 0.3825 - val_accuracy: 0.8948
# Epoch 10/20
# 3188/3188 [==============================] - 69s 22ms/step - loss: 0.1392 - accuracy: 0.9542 - val_loss: 0.3881 - val_accuracy: 0.8952
# Epoch 11/20
# 3188/3188 [==============================] - 68s 21ms/step - loss: 0.1239 - accuracy: 0.9587 - val_loss: 0.3975 - val_accuracy: 0.8945
# Epoch 12/20
# 3188/3188 [==============================] - 70s 22ms/step - loss: 0.1104 - accuracy: 0.9636 - val_loss: 0.4128 - val_accuracy: 0.8938
# Epoch 13/20
# 3188/3188 [==============================] - 70s 22ms/step - loss: 0.0994 - accuracy: 0.9668 - val_loss: 0.4249 - val_accuracy: 0.8945
# Epoch 14/20
# 3188/3188 [==============================] - 68s 21ms/step - loss: 0.0917 - accuracy: 0.9697 - val_loss: 0.4371 - val_accuracy: 0.8934
# Epoch 15/20
# 3188/3188 [==============================] - 70s 22ms/step - loss: 0.0837 - accuracy: 0.9720 - val_loss: 0.4471 - val_accuracy: 0.8937
# Epoch 16/20
# 3188/3188 [==============================] - 69s 22ms/step - loss: 0.0785 - accuracy: 0.9737 - val_loss: 0.4635 - val_accuracy: 0.8933
# Epoch 17/20
# 3188/3188 [==============================] - 68s 21ms/step - loss: 0.0721 - accuracy: 0.9760 - val_loss: 0.4780 - val_accuracy: 0.8926
# Epoch 18/20
# 3188/3188 [==============================] - 71s 22ms/step - loss: 0.0705 - accuracy: 0.9764 - val_loss: 0.4859 - val_accuracy: 0.8925
# Epoch 19/20
# 3188/3188 [==============================] - 73s 23ms/step - loss: 0.0663 - accuracy: 0.9776 - val_loss: 0.5000 - val_accuracy: 0.8919
# Epoch 20/20
# 3188/3188 [==============================] - 81s 25ms/step - loss: 0.0643 - accuracy: 0.9785 - val_loss: 0.5093 - val_accuracy: 0.8928

# %%
history = model.fit(X_train,y_train,
                    batch_size=16,
                    epochs=20,
                    validation_split=0.4,
                    validation_batch_size=16)
# Out:
# Epoch 1/20
# 3188/3188 [==============================] - 73s 23ms/step - loss: 0.0616 - accuracy: 0.9793 - val_loss: 0.5160 - val_accuracy: 0.8921
# Epoch 2/20
# 3188/3188 [==============================] - 72s 23ms/step - loss: 0.0585 - accuracy: 0.9803 - val_loss: 0.5268 - val_accuracy: 0.8921
# Epoch 3/20
# 3188/3188 [==============================] - 82s 26ms/step - loss: 0.0589 - accuracy: 0.9799 - val_loss: 0.5316 - val_accuracy: 0.8913
# Epoch 4/20
# 3188/3188 [==============================] - 72s 23ms/step - loss: 0.0558 - accuracy: 0.9810 - val_loss: 0.5405 - val_accuracy: 0.8914
# Epoch 5/20
# 3188/3188 [==============================] - ETA: 0s - loss: 0.0565 - accuracy: 0.9806
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-d1b60ca05081> in <module>
# ----> 1 history = model.fit(X_train,y_train,
#       2                     batch_size=16,
#       3                     epochs=20,
#       4                     validation_split=0.4,
#       5                     validation_batch_size=16)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1692                             steps_per_execution=self._steps_per_execution,
#    1693                         )
# -> 1694                     val_logs = self.evaluate(
#    1695                         x=val_x,
#    1696                         y=val_y,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2038                         ):
#    2039                             callbacks.on_test_batch_begin(step)
# -> 2040                             tmp_logs = self.test_function(iterator)
#    2041                             if data_handler.should_sync:
#    2042                                 context.async_wait()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     917       # In this case we have not created variables on the first call. So we can
#     918       # run the first trace but we should fail if variables are created.
# --> 919       results = self._variable_creation_fn(*args, **kwds)
#     920       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     921         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # Restoring the model

# %%
from tensorflow.keras.models import model_from_json
with open('model3.json', 'r') as f:
  model=model_from_json(f.read())

# %%
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_28 (InputLayer)          [(None, None)]       0           []
#
#  embedding_27 (Embedding)       (None, None, 256)    9216        ['input_28[0][0]']
#
#  input_29 (InputLayer)          [(None, None)]       0           []
#
#  lstm_33 (LSTM)                 (None, None, 128)    197120      ['embedding_27[0][0]']
#
#  embedding_28 (Embedding)       (None, None, 256)    19968       ['input_29[0][0]']
#
#  lstm_34 (LSTM)                 [(None, 256),        394240      ['lstm_33[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_35 (LSTM)                 [(None, None, 256),  525312      ['embedding_28[0][0]',
#                                  (None, 256),                     'lstm_34[0][1]',
#                                  (None, 256)]                     'lstm_34[0][2]']
#
#  dense_12 (Dense)               (None, None, 78)     20046       ['lstm_35[0][0]']
#
# ==================================================================================================
# Total params: 1,165,902
# Trainable params: 1,165,902
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.load_weights('/content/model3.h5')

# %%
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_28 (InputLayer)          [(None, None)]       0           []
#
#  embedding_27 (Embedding)       (None, None, 256)    9216        ['input_28[0][0]']
#
#  input_29 (InputLayer)          [(None, None)]       0           []
#
#  lstm_33 (LSTM)                 (None, None, 128)    197120      ['embedding_27[0][0]']
#
#  embedding_28 (Embedding)       (None, None, 256)    19968       ['input_29[0][0]']
#
#  lstm_34 (LSTM)                 [(None, 256),        394240      ['lstm_33[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_35 (LSTM)                 [(None, None, 256),  525312      ['embedding_28[0][0]',
#                                  (None, 256),                     'lstm_34[0][1]',
#                                  (None, 256)]                     'lstm_34[0][2]']
#
#  dense_12 (Dense)               (None, None, 78)     20046       ['lstm_35[0][0]']
#
# ==================================================================================================
# Total params: 1,165,902
# Trainable params: 1,165,902
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Model Inference

# %% [markdown]
# ### Creating the encoder and decoder

# %%
encoder = Model(char_input, [state_h, state_c])
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, None)]            0
#
#  embedding (Embedding)       (None, None, 256)         9472
#
#  lstm (LSTM)                 (None, None, 128)         197120
#
#  lstm_1 (LSTM)               [(None, 256),             394240
#                               (None, 256),
#                               (None, 256)]
#
# =================================================================
# Total params: 600,832
# Trainable params: 600,832
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder_input_h = Input(shape=(256,))
decoder_input_c = Input(shape=(256,))
x = embedding_layer(ph_input)
x, decoder_output_h, decoder_output_c = decoder_lstm(x, initial_state=[decoder_input_h, decoder_input_c])
x = softmax_dense(x)
decoder = Model([ph_input] + [decoder_input_h, decoder_input_c], 
                                [x] + [decoder_output_h, decoder_output_c])

# %%
decoder.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, None)]       0           []
#
#  embedding_1 (Embedding)        (None, None, 256)    19712       ['input_4[0][0]']
#
#  input_5 (InputLayer)           [(None, 256)]        0           []
#
#  input_6 (InputLayer)           [(None, 256)]        0           []
#
#  lstm_2 (LSTM)                  [(None, None, 256),  525312      ['embedding_1[1][0]',
#                                  (None, 256),                     'input_5[0][0]',
#                                  (None, 256)]                     'input_6[0][0]']
#
#  dense (Dense)                  (None, None, 77)     19789       ['lstm_2[1][0]']
#
# ==================================================================================================
# Total params: 564,813
# Trainable params: 564,813
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Phenome generation for inference
#
#
# 1.    After passing the complete cell state
# and hidden state information of the encoder, the starseq token is first passed to the decoder along with the state information which produces the next phoneme token.
#
# 2.    Each of these phoneme tokens are then added to the sequential input to generate the subsequent phoneme tokens.

# %%
char_tokenizer.texts_to_sequences(['star'])
# Out:
# [[6, 9, 3, 4]]

# %%
def predict_pronunciation(ch_input):
    input_seq = char_tokenizer.texts_to_sequences([ch_input])

    next_h, next_c = encoder.predict(input_seq)
    #print('encoder done')

    curr_token = np.zeros((1,1))
    curr_token[0][0] = phone_tokenizer.word_index['startseq']

    pred_sentence = ''

    for i in range(max_len_op):
        print('entering decoder')
        output, next_h, next_c = decoder.predict([curr_token] + [next_h, next_c])
        #print(output)
        next_token = np.argmax(output[0, 0, :])
        next_word = phone_tokenizer.index_word[next_token]
        if next_word == 'endseq':
            break
        else:
            pred_sentence += ' ' + next_word
            curr_token[0] = next_token

    return pred_sentence

# %%
predict_pronunciation("sweta")
# Out:
# 1/1 [==============================] - 4s 4s/step
# entering decoder
# 1/1 [==============================] - 0s 67ms/step
# entering decoder
# 1/1 [==============================] - 0s 44ms/step
# entering decoder
# 1/1 [==============================] - 0s 40ms/step
# entering decoder
# 1/1 [==============================] - 0s 31ms/step
# entering decoder
# 1/1 [==============================] - 0s 30ms/step
# entering decoder
# 1/1 [==============================] - 0s 29ms/step
# entering decoder
# 1/1 [==============================] - 0s 34ms/step
# entering decoder
# 1/1 [==============================] - 0s 30ms/step
# entering decoder
# 1/1 [==============================] - 0s 26ms/step
# entering decoder
# 1/1 [==============================] - 0s 33ms/step
# entering decoder
# 1/1 [==============================] - 0s 40ms/step
# entering decoder
# 1/1 [==============================] - 0s 30ms/step
# entering decoder
# 1/1 [==============================] - 0s 32ms/step
# entering decoder
# 1/1 [==============================] - 0s 34ms/step
# entering decoder
# 1/1 [==============================] - 0s 30ms/step
# entering decoder
# 1/1 [==============================] - 0s 33ms/step
# entering decoder
# 1/1 [==============================] - 0s 31ms/step
# entering decoder
# 1/1 [==============================] - 0s 31ms/step
# entering decoder
# 1/1 [==============================] - 0s 28ms/step
# entering decoder
# 1/1 [==============================] - 0s 27ms/step
# entering decoder
# 1/1 [==============================] - 0s 29ms/step
# entering decoder
# 1/1 [==============================] - 0s 28ms/step
# entering decoder
# 1/1 [==============================] - 0s 28ms/step
# entering decoder
# 1/1 [==============================] - 0s 33ms/step
# entering decoder
# 1/1 [==============================] - 0s 32ms/step
# entering decoder
# 1/1 [==============================] - 0s 34ms/step
# entering decoder
# 1/1 [==============================] - 0s 29ms/step
# entering decoder
# 1/1 [==============================] - 0s 28ms/step
# entering decoder
# 1/1 [==============================] - 0s 30ms/step
# entering decoder
# 1/1 [==============================] - 0s 27ms/step
# ' ay0 ay0 eh2 ow1 ae1 ah0 g ah0 g eh1 old old jh aa1 aa1 ao1 ao1 aa1 ao1 ao1 d ih1 ih1 f f f f ay1 ih0 ih0'
